# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import db_utils, sqlalchemy
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn2_circles
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import seaborn as sns
from scipy.stats import fisher_exact
from scipy import stats
import math
import os
import gzip
import re
import glob
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import math

# %%
# Define a function that ensures an element is a list of strings
def ensure_list_of_strings(value):
    if isinstance(value, list):
        return [str(val) for val in value]
    elif isinstance(value, str):
        # Split the string by comma or any other delimiter used in the data
        return [val.strip() for val in value.split(',')]
    else:
        return []

# %%
# Connect to the MySQL database and read the preprocessed 3did into a DataFrame
eng = sqlalchemy.create_engine('mysql://', creator= db_utils.get_connection)
query= pd.read_sql_query('''select * from chopyan_db.3did_agg_DDI_PDB as df''', con= eng)
DDI_CS = pd.DataFrame(query)
DDI_CS
# Out:
#                DDI_type PDB_ID Chain_ID1 DomainID1      DomainName1
# 0       PF00001_PF00001   1gzm         A   PF00001            7tm_1  \
# 1       PF00001_PF00001   1hzx         B   PF00001            7tm_1
# 2       PF00001_PF00001   1l9h         B   PF00001            7tm_1
# 3       PF00001_PF00001   2j4y         A   PF00001            7tm_1
# 4       PF00001_PF00001   2vt4         C   PF00001            7tm_1
# ...                 ...    ...       ...       ...              ...
# 235443  PF18841_PF17433   1wmr         A   PF18841  B_solenoid_dext
# 235444  PF18841_PF17433   1x0c         B   PF18841  B_solenoid_dext
# 235445  PF18841_PF17433   2z8g         A   PF18841  B_solenoid_dext
# 235446  PF18841_PF17433   3wwg         C   PF18841  B_solenoid_dext
# 235447  PF18841_PF17433   6nzs         A   PF18841  B_solenoid_dext
#
#        DomainStart1 DomainEnd1 Chain_ID2 DomainID2      DomainName2
# 0                54        306         B   PF00001            7tm_1  \
# 1                54        246         B   PF00001            7tm_1
# 2                54        246         B   PF00001            7tm_1
# 3                54        306         B   PF00001            7tm_1
# 4                58        343         D   PF00001            7tm_1
# ...             ...        ...       ...       ...              ...
# 235443          321        354         A   PF17433  Glyco_hydro_49N
# 235444          321        354         B   PF17433  Glyco_hydro_49N
# 235445          321        354         A   PF17433  Glyco_hydro_49N
# 235446          321        354         C   PF17433  Glyco_hydro_49N
# 235447          389        421         A   PF17433  Glyco_hydro_49N
#
#        DomainStart2 DomainEnd2  Score   Zscore
# 0                54        306  26.18  7.82923  \
# 1               224        306  42.49  7.03413
# 2               224        306  40.17  9.39410
# 3                54        306  26.85  6.86878
# 4                58        343  20.02  6.36751
# ...             ...        ...    ...      ...
# 235443           19        184   9.52  4.52235
# 235444           19        184   9.52  4.45403
# 235445           19        184   9.24  4.49346
# 235446           19        184   9.24  4.61412
# 235447           52        244   8.92  3.12393
#
#                                               Chain1Iface
# 0       E:196,E:196,E:196,E:196,E:197,N:199,E:201,E:20...  \
# 1       I:54,I:54,I:54,N:55,N:55,N:55,T:58,L:72,L:72,L...
# 2       I:54,I:54,N:55,N:55,N:55,T:58,L:72,L:72,L:72,L...
# 3       N:199,E:201,E:201,E:201,S:202,S:202,I:205,V:20...
# 4       L:152,V:160,T:164,T:164,A:167,I:168,I:168,A:17...
# ...                                                   ...
# 235443  D:341,D:341,D:341,K:343,K:343,V:345,V:345,V:34...
# 235444  D:341,D:341,D:341,K:343,K:343,V:345,V:345,V:34...
# 235445  D:341,D:341,D:341,K:343,K:343,V:345,V:345,V:34...
# 235446  D:341,D:341,D:341,K:343,K:343,V:345,V:345,V:34...
# 235447  N:408,N:408,N:408,N:408,Y:409,K:410,K:410,V:41...
#
#                                               Chain2Iface  isInterchain
# 0       F:228,K:231,E:232,A:233,E:232,F:228,V:227,F:22...             1
# 1       V:300,P:303,V:304,A:299,V:300,P:303,Y:306,V:25...             0
# 2       V:300,P:303,A:299,V:300,P:303,Y:306,V:250,M:25...             0
# 3       Q:236,F:228,K:231,E:232,F:228,E:232,F:228,F:22...             1
# 4       F:315,A:206,A:206,A:210,W:181,A:210,I:214,W:18...             1
# ...                                                   ...           ...
# 235443  R:153,S:182,P:183,S:101,S:182,Q:97,W:99,L:178,...             0
# 235444  R:153,S:182,P:183,S:101,S:182,Q:97,W:99,L:178,...             0
# 235445  R:153,S:182,P:183,S:101,S:182,Q:97,W:99,L:178,...             0
# 235446  R:153,S:182,P:183,S:101,S:182,Q:97,W:99,L:178,...             0
# 235447  D:192,A:193,R:196,E:242,E:242,S:140,E:242,W:13...             0
#
# [235448 rows x 17 columns]

# %%
# Group the DataFrame based in 'DDI_type' so that there is one row per DDI type and keep domain names as columns
# Create a new column holding a list of the two domain names calles 'domain_IDs'
DDI_grouped = DDI_CS.groupby('DDI_type').agg({'DomainName1': 'first', 'DomainName2': 'first'})
DDI_grouped['domain_IDs'] = [[Name1, Name2] for Name1, Name2 in zip(DDI_grouped['DomainName1'].tolist(), DDI_grouped['DomainName2'].tolist())]
DDI_grouped.reset_index(inplace=True)

# %%
DDI_grouped

# %%
# Create a dictionary holding the Pfam-Pfam combination of a DDI as key and the associated domain names as values
# Should later be used to translate the combinations of short name into the aquivalent DDI type 
DDI_type_domainIDs = {}
for DDI_type, domain_IDs in zip(DDI_grouped['DDI_type'].tolist(), DDI_grouped['domain_IDs'].tolist()):
    DDI_type_domainIDs[DDI_type] = domain_IDs

# %%
DDI_type_domainIDs
# Out:
# {'PF00001_PF00001': ['7tm_1', '7tm_1'],
#  'PF00001_PF00048': ['7tm_1', 'IL8'],
#  'PF00001_PF00085': ['7tm_1', 'Thioredoxin'],
#  'PF00001_PF00087': ['7tm_1', 'Toxin_TOLIP'],
#  'PF00001_PF00322': ['7tm_1', 'Endothelin'],
#  'PF00001_PF00339': ['7tm_1', 'Arrestin_N'],
#  'PF00001_PF00400': ['7tm_1', 'WD40'],
#  'PF00001_PF00503': ['7tm_1', 'G-alpha'],
#  'PF00001_PF00516': ['7tm_1', 'GP120'],
#  'PF00001_PF00534': ['7tm_1', 'Glycos_transf_1'],
#  'PF00001_PF00959': ['7tm_1', 'Phage_lysozyme'],
#  'PF00001_PF02202': ['7tm_1', 'Tachykinin'],
#  'PF00001_PF02752': ['7tm_1', 'Arrestin_C'],
#  'PF00001_PF07361': ['7tm_1', 'Cytochrom_B562'],
#  'PF00001_PF07686': ['7tm_1', 'V-set'],
#  'PF00001_PF10413': ['7tm_1', 'Rhodopsin_N'],
#  'PF00002_PF00002': ['7tm_2', '7tm_2'],
#  'PF00002_PF00123': ['7tm_2', 'Hormone_2'],
#  'PF00002_PF00214': ['7tm_2', 'Calc_CGRP_IAPP'],
#  'PF00002_PF00301': ['7tm_2', 'Rubredoxin'],
#  'PF00002_PF00473': ['7tm_2', 'CRF'],
#  'PF00002_PF00503': ['7tm_2', 'G-alpha'],
#  'PF00002_PF00534': ['7tm_2', 'Glycos_transf_1'],
#  'PF00002_PF00959': ['7tm_2', 'Phage_lysozyme'],
#  'PF00002_PF01279': ['7tm_2', 'Parathyroid'],
#  'PF00002_PF02793': ['7tm_2', 'HRM'],
#  'PF00002_PF04901': ['7tm_2', 'RAMP'],
#  'PF00002_PF07361': ['7tm_2', 'Cytochrom_B562'],
#  'PF00002_PF07686': ['7tm_2', 'V-set'],
#  'PF00003_PF00003': ['7tm_3', '7tm_3'],
#  'PF00003_PF00959': ['7tm_3', 'Phage_lysozyme'],
#  'PF00003_PF07361': ['7tm_3', 'Cytochrom_B562'],
#  'PF00003_PF07562': ['7tm_3', 'NCD3G'],
#  'PF00004_PF00004': ['AAA', 'AAA'],
#  'PF00004_PF00101': ['AAA', 'RuBisCO_small'],
#  'PF00004_PF00227': ['AAA', 'Proteasome'],
#  'PF00004_PF00240': ['AAA', 'ubiquitin'],
#  'PF00004_PF00705': ['AAA', 'PCNA_N'],
#  'PF00004_PF01434': ['AAA', 'Peptidase_M41'],
#  'PF00004_PF02359': ['AAA', 'CDC48_N'],
#  'PF00004_PF02747': ['AAA', 'PCNA_C'],
#  'PF00004_PF02788': ['AAA', 'RuBisCO_large_N'],
#  'PF00004_PF02861': ['AAA', 'Clp_N'],
#  'PF00004_PF02916': ['AAA', 'DNA_PPF'],
#  'PF00004_PF02933': ['AAA', 'CDC48_2'],
#  'PF00004_PF04084': ['AAA', 'ORC2'],
#  'PF00004_PF05020': ['AAA', 'zf-NPL4'],
#  'PF00004_PF05021': ['AAA', 'NPL4'],
#  'PF00004_PF05362': ['AAA', 'Lon_C'],
#  'PF00004_PF06581': ['AAA', 'p31comet'],
#  'PF00004_PF07724': ['AAA', 'AAA_2'],
#  'PF00004_PF08519': ['AAA', 'RFC1'],
#  'PF00004_PF08542': ['AAA', 'Rep_fac_C'],
#  'PF00004_PF08740': ['AAA', 'BCS1_N'],
#  'PF00004_PF09079': ['AAA', 'Cdc6_C'],
#  'PF00004_PF09116': ['AAA', 'gp45-slide_C'],
#  'PF00004_PF09336': ['AAA', 'Vps4_C'],
#  'PF00004_PF10431': ['AAA', 'ClpB_D2-small'],
#  'PF00004_PF10584': ['AAA', 'Proteasome_A_N'],
#  'PF00004_PF10602': ['AAA', 'RPN7'],
#  'PF00004_PF13177': ['AAA', 'DNA_pol3_delta2'],
#  'PF00004_PF13191': ['AAA', 'AAA_16'],
#  'PF00004_PF13401': ['AAA', 'AAA_22'],
#  'PF00004_PF14629': ['AAA', 'ORC4_C'],
#  'PF00004_PF16193': ['AAA', 'AAA_assoc_2'],
#  'PF00004_PF16450': ['AAA', 'Prot_ATP_ID_OB'],
#  'PF00004_PF16790': ['AAA', 'Phage_clamp_A'],
#  'PF00004_PF17862': ['AAA', 'AAA_lid_3'],
#  'PF00004_PF17866': ['AAA', 'AAA_lid_6'],
#  'PF00004_PF17871': ['AAA', 'AAA_lid_9'],
#  'PF00004_PF17872': ['AAA', 'AAA_lid_10'],
#  'PF00004_PF18137': ['AAA', 'ORC_WH_C'],
#  'PF00004_PF18138': ['AAA', 'bacHORMA_1'],
#  'PF00005_PF00005': ['ABC_tran', 'ABC_tran'],
#  'PF00005_PF00281': ['ABC_tran', 'Ribosomal_L5'],
#  'PF00005_PF00358': ['ABC_tran', 'PTS_EIIA_1'],
#  'PF00005_PF00528': ['ABC_tran', 'BPD_transp_1'],
#  'PF00005_PF00687': ['ABC_tran', 'Ribosomal_L1'],
#  'PF00005_PF00781': ['ABC_tran', 'DAGK_cat'],
#  'PF00005_PF01032': ['ABC_tran', 'FecCD'],
#  'PF00005_PF01458': ['ABC_tran', 'UPF0051'],
#  'PF00005_PF02361': ['ABC_tran', 'CbiQ'],
#  'PF00005_PF02405': ['ABC_tran', 'MlaE'],
#  'PF00005_PF02687': ['ABC_tran', 'FtsX'],
#  'PF00005_PF03412': ['ABC_tran', 'Peptidase_C39'],
#  'PF00005_PF03459': ['ABC_tran', 'TOBE'],
#  'PF00005_PF03739': ['ABC_tran', 'LptF_LptG'],
#  'PF00005_PF07686': ['ABC_tran', 'V-set'],
#  'PF00005_PF08352': ['ABC_tran', 'oligo_HPY'],
#  'PF00005_PF12399': ['ABC_tran', 'BCA_ABC_TP_C'],
#  'PF00005_PF12848': ['ABC_tran', 'ABC_tran_Xtn'],
#  'PF00005_PF13466': ['ABC_tran', 'STAS_2'],
#  'PF00005_PF14396': ['ABC_tran', 'CFTR_R'],
#  'PF00005_PF17755': ['ABC_tran', 'UvrA_DNA-bind'],
#  'PF00005_PF17760': ['ABC_tran', 'UvrA_inter'],
#  'PF00005_PF17777': ['ABC_tran', 'RL10P_insert'],
#  'PF00006_PF00006': ['ATP-synt_ab', 'ATP-synt_ab'],
#  'PF00006_PF00306': ['ATP-synt_ab', 'ATP-synt_ab_C'],
#  'PF00006_PF00575': ['ATP-synt_ab', 'S1'],
#  'PF00006_PF01991': ['ATP-synt_ab', 'vATP-synt_E'],
#  'PF00006_PF02874': ['ATP-synt_ab', 'ATP-synt_ab_N'],
#  'PF00006_PF04568': ['ATP-synt_ab', 'IATP'],
#  'PF00006_PF05873': ['ATP-synt_ab', 'Mt_ATP-synt_D'],
#  'PF00006_PF07497': ['ATP-synt_ab', 'Rho_RNA_bind'],
#  'PF00006_PF16886': ['ATP-synt_ab', 'ATP-synt_ab_Xtn'],
#  'PF00006_PF18269': ['ATP-synt_ab', 'T3SS_ATPase_C'],
#  'PF00007_PF00007': ['Cys_knot', 'Cys_knot'],
#  'PF00007_PF00236': ['Cys_knot', 'Hormone_6'],
#  'PF00007_PF01392': ['Cys_knot', 'Fz'],
#  'PF00007_PF07686': ['Cys_knot', 'V-set'],
#  'PF00007_PF13306': ['Cys_knot', 'LRR_5'],
#  'PF00008_PF00008': ['EGF', 'EGF'],
#  'PF00008_PF00039': ['EGF', 'fn1'],
#  'PF00008_PF00059': ['EGF', 'Lectin_C'],
#  'PF00008_PF00084': ['EGF', 'Sushi'],
#  'PF00008_PF00089': ['EGF', 'Trypsin'],
#  'PF00008_PF00757': ['EGF', 'Furin-like'],
#  'PF00008_PF01030': ['EGF', 'Recep_L_domain'],
#  'PF00008_PF01108': ['EGF', 'Tissue_fac'],
#  'PF00008_PF01501': ['EGF', 'Glyco_transf_8'],
#  'PF00008_PF02210': ['EGF', 'Laminin_G_2'],
#  'PF00008_PF05686': ['EGF', 'Glyco_transf_90'],
#  'PF00008_PF07645': ['EGF', 'EGF_CA'],
#  'PF00008_PF07686': ['EGF', 'V-set'],
#  'PF00008_PF09294': ['EGF', 'Interfer-bind'],
#  'PF00008_PF10250': ['EGF', 'O-FucT'],
#  'PF00008_PF13181': ['EGF', 'TPR_8'],
#  'PF00008_PF13432': ['EGF', 'TPR_16'],
#  'PF00008_PF14670': ['EGF', 'FXa_inhibition'],
#  'PF00009_PF00009': ['GTP_EFTU', 'GTP_EFTU'],
#  'PF00009_PF00347': ['GTP_EFTU', 'Ribosomal_L6'],
#  'PF00009_PF01423': ['GTP_EFTU', 'LSM'],
#  'PF00009_PF01507': ['GTP_EFTU', 'PAPS_reduct'],
#  'PF00009_PF01873': ['GTP_EFTU', 'eIF-5_eIF-2B'],
#  'PF00009_PF01912': ['GTP_EFTU', 'eIF-6'],
#  'PF00009_PF01926': ['GTP_EFTU', 'MMR_HSR1'],
#  'PF00009_PF03143': ['GTP_EFTU', 'GTP_EFTU_D3'],
#  'PF00009_PF03144': ['GTP_EFTU', 'GTP_EFTU_D2'],
#  'PF00009_PF03431': ['GTP_EFTU', 'RNA_replicase_B'],
#  'PF00009_PF03463': ['GTP_EFTU', 'eRF1_1'],
#  'PF00009_PF03464': ['GTP_EFTU', 'eRF1_2'],
#  'PF00009_PF06421': ['GTP_EFTU', 'LepA_C'],
#  'PF00009_PF08083': ['GTP_EFTU', 'PROCN'],
#  'PF00009_PF09173': ['GTP_EFTU', 'eIF2_C'],
#  'PF00009_PF11987': ['GTP_EFTU', 'IF-2'],
#  'PF00009_PF15538': ['GTP_EFTU', 'Ntox46'],
#  'PF00009_PF16658': ['GTP_EFTU', 'RF3_C'],
#  'PF00009_PF17777': ['GTP_EFTU', 'RL10P_insert'],
#  'PF00010_PF00010': ['HLH', 'HLH'],
#  'PF00010_PF00412': ['HLH', 'LIM'],
#  'PF00010_PF00989': ['HLH', 'PAS'],
#  'PF00010_PF02344': ['HLH', 'Myc-LZ'],
#  'PF00011_PF00011': ['HSP20', 'HSP20'],
#  'PF00012_PF00012': ['HSP70', 'HSP70'],
#  'PF00012_PF16782': ['HSP70', 'SIL1'],
#  'PF00013_PF00013': ['KH_1', 'KH_1'],
#  'PF00013_PF00575': ['KH_1', 'S1'],
#  'PF00013_PF01138': ['KH_1', 'RNase_PH'],
#  'PF00013_PF16274': ['KH_1', 'Qua1'],
#  'PF00013_PF16544': ['KH_1', 'STAR_dimer'],
#  'PF00014_PF00014': ['Kunitz_BPTI', 'Kunitz_BPTI'],
#  'PF00014_PF00068': ['Kunitz_BPTI', 'Phospholip_A2_1'],
#  'PF00014_PF00089': ['Kunitz_BPTI', 'Trypsin'],
#  'PF00014_PF00246': ['Kunitz_BPTI', 'Peptidase_M14'],
#  'PF00014_PF00949': ['Kunitz_BPTI', 'Peptidase_S7'],
#  'PF00014_PF07502': ['Kunitz_BPTI', 'MANEC'],
#  'PF00014_PF07686': ['Kunitz_BPTI', 'V-set'],
#  'PF00015_PF00015': ['MCPsignal', 'MCPsignal'],
#  'PF00016_PF00016': ['RuBisCO_large', 'RuBisCO_large'],
#  'PF00016_PF00101': ['RuBisCO_large', 'RuBisCO_small'],
#  'PF00016_PF02788': ['RuBisCO_large', 'RuBisCO_large_N'],
#  'PF00016_PF18087': ['RuBisCO_large', 'RuBisCo_chap_C'],
#  'PF00017_PF00017': ['SH2', 'SH2'],
#  'PF00017_PF00018': ['SH2', 'SH3_1'],
#  'PF00017_PF00041': ['SH2', 'fn3'],
#  'PF00017_PF00102': ['SH2', 'Y_phosphatase'],
#  'PF00017_PF07525': ['SH2', 'SOCS_box'],
#  'PF00017_PF07653': ['SH2', 'SH3_2'],
#  'PF00018_PF00018': ['SH3_1', 'SH3_1'],
#  'PF00018_PF00089': ['SH3_1', 'Trypsin'],
#  'PF00018_PF00240': ['SH3_1', 'ubiquitin'],
#  'PF00018_PF07653': ['SH3_1', 'SH3_2'],
#  'PF00018_PF08944': ['SH3_1', 'p47_phox_C'],
#  'PF00019_PF00019': ['TGF_beta', 'TGF_beta'],
#  'PF00019_PF00041': ['TGF_beta', 'fn3'],
#  'PF00019_PF00688': ['TGF_beta', 'TGFb_propeptide'],
#  'PF00019_PF07686': ['TGF_beta', 'V-set'],
#  'PF00019_PF08917': ['TGF_beta', 'ecTbetaR2'],
#  'PF00020_PF00020': ['TNFR_c6', 'TNFR_c6'],
#  'PF00020_PF07686': ['TNFR_c6', 'V-set'],
#  'PF00020_PF16758': ['TNFR_c6', 'UL141'],
#  'PF00021_PF00021': ['UPAR_LY6', 'UPAR_LY6'],
#  'PF00021_PF07686': ['UPAR_LY6', 'V-set'],
#  'PF00022_PF00022': ['Actin', 'Actin'],
#  'PF00022_PF00059': ['Actin', 'Lectin_C'],
#  'PF00022_PF00063': ['Actin', 'Myosin_head'],
#  'PF00022_PF00069': ['Actin', 'Pkinase'],
#  'PF00022_PF00132': ['Actin', 'Hexapep'],
#  'PF00022_PF00149': ['Actin', 'Metallophos'],
#  'PF00022_PF00176': ['Actin', 'SNF2_N'],
#  'PF00022_PF00235': ['Actin', 'Profilin'],
#  'PF00022_PF00241': ['Actin', 'Cofilin_ADF'],
#  'PF00022_PF00261': ['Actin', 'Tropomyosin'],
#  'PF00022_PF00273': ['Actin', 'Serum_albumin'],
#  'PF00022_PF00307': ['Actin', 'CH'],
#  'PF00022_PF00400': ['Actin', 'WD40'],
#  'PF00022_PF00620': ['Actin', 'RhoGAP'],
#  'PF00022_PF00626': ['Actin', 'Gelsolin'],
#  'PF00022_PF00992': ['Actin', 'Troponin'],
#  'PF00022_PF01044': ['Actin', 'Vinculin'],
#  'PF00022_PF01115': ['Actin', 'F_actin_cap_B'],
#  'PF00022_PF01213': ['Actin', 'CAP_N'],
#  'PF00022_PF01267': ['Actin', 'F-actin_cap_A'],
#  'PF00022_PF01290': ['Actin', 'Thymosin'],
#  'PF00022_PF02181': ['Actin', 'FH2'],
#  'PF00022_PF02205': ['Actin', 'WH2'],
#  'PF00022_PF02755': ['Actin', 'RPEL'],
#  'PF00022_PF03250': ['Actin', 'Tropomodulin'],
#  'PF00022_PF03372': ['Actin', 'Exo_endo_phos'],
#  'PF00022_PF04045': ['Actin', 'P34-Arc'],
#  'PF00022_PF04062': ['Actin', 'P21-Arc'],
#  'PF00022_PF04699': ['Actin', 'P16-Arc'],
#  'PF00022_PF04912': ['Actin', 'Dynamitin'],
#  'PF00022_PF05502': ['Actin', 'Dynactin_p62'],
#  'PF00022_PF06068': ['Actin', 'TIP49'],
#  'PF00022_PF07529': ['Actin', 'HSA'],
#  'PF00022_PF07679': ['Actin', 'I-set'],
#  'PF00022_PF07686': ['Actin', 'V-set'],
#  'PF00022_PF08265': ['Actin', 'YL1_C'],
#  'PF00022_PF08385': ['Actin', 'DHC_N1'],
#  'PF00022_PF08603': ['Actin', 'CAP_C'],
#  'PF00022_PF09164': ['Actin', 'VitD-bind_III'],
#  'PF00022_PF09510': ['Actin', 'Rtt102p'],
#  'PF00022_PF09632': ['Actin', 'Rac1'],
#  'PF00022_PF13833': ['Actin', 'EF-hand_8'],
#  'PF00022_PF13892': ['Actin', 'DBINO'],
#  'PF00023_PF00023': ['Ank', 'Ank'],
#  'PF00023_PF00069': ['Ank', 'Pkinase'],
#  'PF00023_PF00071': ['Ank', 'Ras'],
#  'PF00023_PF00091': ['Ank', 'Tubulin'],
#  'PF00023_PF00452': ['Ank', 'Bcl-2'],
#  'PF00023_PF00656': ['Ank', 'Peptidase_C14'],
#  'PF00023_PF00856': ['Ank', 'SET'],
#  'PF00023_PF01353': ['Ank', 'GFP'],
#  'PF00023_PF07679': ['Ank', 'I-set'],
#  'PF00023_PF07686': ['Ank', 'V-set'],
#  'PF00023_PF09067': ['Ank', 'EpoR_lig-bind'],
#  'PF00023_PF12796': ['Ank', 'Ank_2'],
#  'PF00023_PF13354': ['Ank', 'Beta-lactamase2'],
#  'PF00023_PF13416': ['Ank', 'SBP_bac_8'],
#  'PF00023_PF13621': ['Ank', 'Cupin_8'],
#  'PF00023_PF13637': ['Ank', 'Ank_4'],
#  'PF00023_PF13857': ['Ank', 'Ank_5'],
#  'PF00023_PF16179': ['Ank', 'RHD_dimer'],
#  'PF00024_PF00024': ['PAN_1', 'PAN_1'],
#  'PF00024_PF00089': ['PAN_1', 'Trypsin'],
#  'PF00024_PF14295': ['PAN_1', 'PAN_4'],
#  'PF00025_PF00025': ['Arf', 'Arf'],
#  'PF00025_PF00169': ['Arf', 'PH'],
#  'PF00025_PF00626': ['Arf', 'Gelsolin'],
#  'PF00025_PF01369': ['Arf', 'Sec7'],
#  'PF00025_PF01375': ['Arf', 'Enterotoxin_a'],
#  'PF00025_PF01412': ['Arf', 'ArfGap'],
#  'PF00025_PF01465': ['Arf', 'GRIP'],
#  'PF00025_PF03259': ['Arf', 'Robl_LC7'],
#  'PF00025_PF03543': ['Arf', 'Peptidase_C58'],
#  'PF00025_PF04810': ['Arf', 'zf-Sec23_Sec24'],
#  'PF00025_PF04811': ['Arf', 'Sec23_trunk'],
#  'PF00025_PF04815': ['Arf', 'Sec23_helical'],
#  'PF00025_PF05351': ['Arf', 'GMP_PDE_delta'],
#  'PF00025_PF06456': ['Arf', 'Arfaptin'],
#  'PF00025_PF06872': ['Arf', 'EspG'],
#  'PF00025_PF07986': ['Arf', 'TBCC'],
#  'PF00025_PF11549': ['Arf', 'Sec31'],
#  'PF00025_PF14779': ['Arf', 'BBS1'],
#  'PF00025_PF16213': ['Arf', 'DCB'],
#  'PF00025_PF16453': ['Arf', 'IQ_SEC7_PH'],
#  'PF00025_PF16471': ['Arf', 'JIP_LZII'],
#  'PF00025_PF16540': ['Arf', 'MKLP1_Arf_bdg'],
#  'PF00025_PF16893': ['Arf', 'fn3_2'],
#  'PF00025_PF18308': ['Arf', 'GGA_N-GAT'],
#  'PF00026_PF00018': ['Asp', 'SH3_1'],
#  'PF00026_PF00026': ['Asp', 'Asp'],
#  'PF00026_PF00079': ['Asp', 'Serpin'],
#  'PF00026_PF06394': ['Asp', 'Pepsin-I3'],
#  'PF00026_PF07686': ['Asp', 'V-set'],
#  'PF00026_PF10466': ['Asp', 'Inhibitor_I34'],
#  'PF00027_PF00027': ['cNMP_binding', 'cNMP_binding'],
#  'PF00028_PF00028': ['Cadherin', 'Cadherin'],
#  'PF00028_PF00059': ['Cadherin', 'Lectin_C'],
#  'PF00028_PF02351': ['Cadherin', 'GDNF'],
#  'PF00028_PF07686': ['Cadherin', 'V-set'],
#  'PF00028_PF08266': ['Cadherin', 'Cadherin_2'],
#  'PF00028_PF12799': ['Cadherin', 'LRR_4'],
#  'PF00028_PF17756': ['Cadherin', 'RET_CLD1'],
#  'PF00028_PF17812': ['Cadherin', 'RET_CLD3'],
#  'PF00028_PF17993': ['Cadherin', 'HA70_C'],
#  'PF00028_PF18432': ['Cadherin', 'ECD'],
#  'PF00029_PF00029': ['Connexin', 'Connexin'],
#  'PF00030_PF00030': ['Crystall', 'Crystall'],
#  'PF00031_PF00031': ['Cystatin', 'Cystatin'],
#  'PF00031_PF00112': ['Cystatin', 'Peptidase_C1'],
#  'PF00031_PF00509': ['Cystatin', 'Hemagglutinin'],
#  'PF00031_PF01650': ['Cystatin', 'Peptidase_C13'],
#  'PF00032_PF00032': ['Cytochrom_B_C', 'Cytochrom_B_C'],
#  'PF00032_PF00033': ['Cytochrom_B_C', 'Cytochrome_B'],
#  'PF00032_PF00355': ['Cytochrom_B_C', 'Rieske'],
#  'PF00032_PF02167': ['Cytochrom_B_C', 'Cytochrom_C1'],
#  'PF00032_PF02271': ['Cytochrom_B_C', 'UCR_14kD'],
#  'PF00032_PF02529': ['Cytochrom_B_C', 'PetG'],
#  'PF00032_PF02939': ['Cytochrom_B_C', 'UcrQ'],
#  'PF00033_PF00033': ['Cytochrome_B', 'Cytochrome_B'],
#  'PF00033_PF00355': ['Cytochrome_B', 'Rieske'],
#  'PF00033_PF02271': ['Cytochrome_B', 'UCR_14kD'],
#  'PF00033_PF02529': ['Cytochrome_B', 'PetG'],
#  'PF00033_PF02921': ['Cytochrome_B', 'UCR_TM'],
#  'PF00033_PF02939': ['Cytochrome_B', 'UcrQ'],
#  'PF00033_PF03742': ['Cytochrome_B', 'PetN'],
#  'PF00033_PF09796': ['Cytochrome_B', 'QCR10'],
#  'PF00033_PF10399': ['Cytochrome_B', 'UCR_Fe-S_N'],
#  'PF00034_PF00033': ['Cytochrom_C', 'Cytochrome_B'],
#  'PF00034_PF00034': ['Cytochrom_C', 'Cytochrom_C'],
#  'PF00034_PF00111': ['Cytochrom_C', 'Fer2'],
#  'PF00034_PF00124': ['Cytochrom_C', 'Photo_RC'],
#  'PF00034_PF00141': ['Cytochrom_C', 'peroxidase'],
#  'PF00034_PF00355': ['Cytochrom_C', 'Rieske'],
#  'PF00034_PF00400': ['Cytochrom_C', 'WD40'],
#  'PF00034_PF02167': ['Cytochrom_C', 'Cytochrom_C1'],
#  'PF00034_PF02239': ['Cytochrom_C', 'Cytochrom_D1'],
#  'PF00034_PF07686': ['Cytochrom_C', 'V-set'],
#  'PF00034_PF13187': ['Cytochrom_C', 'Fer4_9'],
#  'PF00034_PF13370': ['Cytochrom_C', 'Fer4_13'],
#  'PF00034_PF13442': ['Cytochrom_C', 'Cytochrome_CBB3'],
#  'PF00034_PF13447': ['Cytochrom_C', 'Multi-haem_cyto'],
#  'PF00035_PF00035': ['dsrm', 'dsrm'],
#  'PF00036_PF00036': ['EF-hand_1', 'EF-hand_1'],
#  'PF00036_PF00069': ['EF-hand_1', 'Pkinase'],
#  'PF00036_PF00612': ['EF-hand_1', 'IQ'],
#  'PF00036_PF01023': ['EF-hand_1', 'S_100'],
#  'PF00036_PF01353': ['EF-hand_1', 'GFP'],
#  'PF00036_PF08030': ['EF-hand_1', 'NAD_binding_6'],
#  'PF00036_PF13202': ['EF-hand_1', 'EF-hand_5'],
#  'PF00036_PF13499': ['EF-hand_1', 'EF-hand_7'],
#  'PF00036_PF13833': ['EF-hand_1', 'EF-hand_8'],
#  'PF00037_PF00037': ['Fer4', 'Fer4'],
#  'PF00037_PF00164': ['Fer4', 'Ribosom_S12_S23'],
#  'PF00037_PF00374': ['Fer4', 'NiFeSe_Hases'],
#  'PF00037_PF01058': ['Fer4', 'Oxidored_q6'],
#  'PF00037_PF01568': ['Fer4', 'Molydop_binding'],
#  'PF00037_PF03465': ['Fer4', 'eRF1_3'],
#  'PF00037_PF04068': ['Fer4', 'RLI'],
#  'PF00037_PF04422': ['Fer4', 'FrhB_FdhB_N'],
#  'PF00037_PF04432': ['Fer4', 'FrhB_FdhB_C'],
#  'PF00037_PF04879': ['Fer4', 'Molybdop_Fe4S4'],
#  'PF00037_PF10588': ['Fer4', 'NADH-G_4Fe-4S_3'],
#  'PF00038_PF00038': ['Filament', 'Filament'],
#  'PF00038_PF06632': ['Filament', 'XRCC4'],
#  'PF00039_PF00039': ['fn1', 'fn1'],
#  'PF00039_PF00040': ['fn1', 'fn2'],
#  'PF00040_PF00040': ['fn2', 'fn2'],
#  'PF00041_PF00041': ['fn3', 'fn3'],
#  'PF00041_PF00047': ['fn3', 'ig'],
#  'PF00042_PF00042': ['Globin', 'Globin'],
#  'PF00042_PF00057': ['Globin', 'Ldl_recept_a'],
#  'PF00042_PF00089': ['Globin', 'Trypsin'],
#  'PF00042_PF00175': ['Globin', 'NAD_binding_1'],
#  'PF00042_PF05031': ['Globin', 'NEAT'],
#  'PF00042_PF16960': ['Globin', 'HpuA'],
#  'PF00043_PF00043': ['GST_C', 'GST_C'],
#  'PF00043_PF02798': ['GST_C', 'GST_N'],
#  'PF00043_PF13409': ['GST_C', 'GST_N_2'],
#  'PF00043_PF13417': ['GST_C', 'GST_N_3'],
#  'PF00043_PF14497': ['GST_C', 'GST_C_3'],
#  'PF00043_PF18485': ['GST_C', 'GST_N_5'],
#  'PF00043_PF18569': ['GST_C', 'Thioredoxin_16'],
#  'PF00044_PF00044': ['Gp_dh_N', 'Gp_dh_N'],
#  'PF00045_PF00045': ['Hemopexin', 'Hemopexin'],
#  'PF00045_PF00413': ['Hemopexin', 'Peptidase_M10'],
#  'PF00045_PF00965': ['Hemopexin', 'TIMP'],
#  'PF00045_PF01471': ['Hemopexin', 'PG_binding_1'],
#  'PF00046_PF00046': ['Homeodomain', 'Homeodomain'],
#  'PF00046_PF00157': ['Homeodomain', 'Pou'],
#  'PF00046_PF00319': ['Homeodomain', 'SRF-TF'],
#  'PF00046_PF00907': ['Homeodomain', 'T-box'],
#  'PF00046_PF01547': ['Homeodomain', 'SBP_bac_1'],
#  'PF00046_PF16878': ['Homeodomain', 'SIX1_SD'],
#  'PF00047_PF00047': ['ig', 'ig'],
#  'PF00048_PF00048': ['IL8', 'IL8'],
#  'PF00048_PF02250': ['IL8', 'Orthopox_35kD'],
#  'PF00048_PF07686': ['IL8', 'V-set'],
#  'PF00048_PF09213': ['IL8', 'M3'],
#  'PF00049_PF00041': ['Insulin', 'fn3'],
#  'PF00049_PF00049': ['Insulin', 'Insulin'],
#  'PF00049_PF00086': ['Insulin', 'Thyroglobulin_1'],
#  'PF00049_PF00675': ['Insulin', 'Peptidase_M16'],
#  'PF00049_PF01030': ['Insulin', 'Recep_L_domain'],
#  'PF00049_PF05193': ['Insulin', 'Peptidase_M16_C'],
#  'PF00049_PF07686': ['Insulin', 'V-set'],
#  'PF00049_PF16187': ['Insulin', 'Peptidase_M16_M'],
#  'PF00050_PF00050': ['Kazal_1', 'Kazal_1'],
#  'PF00050_PF00082': ['Kazal_1', 'Peptidase_S8'],
#  'PF00050_PF00089': ['Kazal_1', 'Trypsin'],
#  'PF00050_PF10591': ['Kazal_1', 'SPARC_Ca_bdg'],
#  'PF00051_PF00021': ['Kringle', 'UPAR_LY6'],
#  'PF00051_PF00024': ['Kringle', 'PAN_1'],
#  'PF00051_PF00051': ['Kringle', 'Kringle'],
#  'PF00051_PF00073': ['Kringle', 'Rhv'],
#  'PF00051_PF00089': ['Kringle', 'Trypsin'],
#  'PF00051_PF01822': ['Kringle', 'WSC'],
#  'PF00051_PF07686': ['Kringle', 'V-set'],
#  'PF00051_PF12107': ['Kringle', 'VEK-30'],
#  'PF00053_PF00041': ['Laminin_EGF', 'fn3'],
#  'PF00053_PF00053': ['Laminin_EGF', 'Laminin_EGF'],
#  'PF00053_PF00055': ['Laminin_EGF', 'Laminin_N'],
#  'PF00053_PF00058': ['Laminin_EGF', 'Ldl_recept_b'],
#  'PF00054_PF00054': ['Laminin_G_1', 'Laminin_G_1'],
#  'PF00054_PF00058': ['Laminin_G_1', 'Ldl_recept_b'],
#  'PF00054_PF02210': ['Laminin_G_1', 'Laminin_G_2'],
#  'PF00054_PF06009': ['Laminin_G_1', 'Laminin_II'],
#  'PF00055_PF00041': ['Laminin_N', 'fn3'],
#  'PF00056_PF00056': ['Ldh_1_N', 'Ldh_1_N'],
#  'PF00057_PF00057': ['Ldl_recept_a', 'Ldl_recept_a'],
#  'PF00057_PF00058': ['Ldl_recept_a', 'Ldl_recept_b'],
#  'PF00057_PF00073': ['Ldl_recept_a', 'Rhv'],
#  'PF00057_PF00084': ['Ldl_recept_a', 'Sushi'],
#  'PF00057_PF00089': ['Ldl_recept_a', 'Trypsin'],
#  'PF00057_PF00090': ['Ldl_recept_a', 'TSP_1'],
#  'PF00057_PF00530': ['Ldl_recept_a', 'SRCR'],
#  'PF00057_PF00974': ['Ldl_recept_a', 'Rhabdo_glycop'],
#  'PF00057_PF01823': ['Ldl_recept_a', 'MACPF'],
#  'PF00057_PF09014': ['Ldl_recept_a', 'Sushi_2'],
#  'PF00058_PF00058': ['Ldl_recept_b', 'Ldl_recept_b'],
#  'PF00058_PF05463': ['Ldl_recept_b', 'Sclerostin'],
#  'PF00058_PF07686': ['Ldl_recept_b', 'V-set'],
#  'PF00059_PF00040': ['Lectin_C', 'fn2'],
#  'PF00059_PF00041': ['Lectin_C', 'fn3'],
#  'PF00059_PF00059': ['Lectin_C', 'Lectin_C'],
#  'PF00059_PF00092': ['Lectin_C', 'VWA'],
#  'PF00059_PF00129': ['Lectin_C', 'MHC_I'],
#  'PF00059_PF00229': ['Lectin_C', 'TNF'],
#  'PF00059_PF08391': ['Lectin_C', 'Ly49'],
#  'PF00059_PF09006': ['Lectin_C', 'Surfac_D-trimer'],
#  'PF00059_PF12216': ['Lectin_C', 'm04gp34like'],
#  'PF00059_PF14586': ['Lectin_C', 'MHC_I_2'],
#  'PF00060_PF00060': ['Lig_chan', 'Lig_chan'],
#  'PF00060_PF00497': ['Lig_chan', 'SBP_bac_3'],
#  'PF00060_PF00822': ['Lig_chan', 'PMP22_Claudin'],
#  'PF00060_PF10613': ['Lig_chan', 'Lig_chan-Glu_bd'],
#  'PF00061_PF00041': ['Lipocalin', 'fn3'],
#  'PF00061_PF00061': ['Lipocalin', 'Lipocalin'],
#  'PF00061_PF00341': ['Lipocalin', 'PDGF'],
#  'PF00061_PF00576': ['Lipocalin', 'Transthyretin'],
#  'PF00061_PF01823': ['Lipocalin', 'MACPF'],
#  'PF00061_PF07686': ['Lipocalin', 'V-set'],
#  'PF00062_PF00041': ['Lys', 'fn3'],
#  'PF00062_PF00062': ['Lys', 'Lys'],
#  'PF00062_PF01336': ['Lys', 'tRNA_anti-codon'],
#  'PF00062_PF07686': ['Lys', 'V-set'],
#  'PF00062_PF09864': ['Lys', 'MliC'],
#  'PF00062_PF13739': ['Lys', 'PdaC'],
#  'PF00062_PF14604': ['Lys', 'SH3_9'],
#  'PF00063_PF00063': ['Myosin_head', 'Myosin_head'],
#  'PF00063_PF00261': ['Myosin_head', 'Tropomyosin'],
#  'PF00063_PF00435': ['Myosin_head', 'Spectrin'],
#  'PF00063_PF01576': ['Myosin_head', 'Myosin_tail_1'],
#  'PF00063_PF18597': ['Myosin_head', 'SH3_19'],
#  'PF00064_PF00064': ['Neur', 'Neur'],
#  'PF00064_PF07686': ['Neur', 'V-set'],
#  'PF00066_PF00066': ['Notch', 'Notch'],
#  'PF00066_PF07686': ['Notch', 'V-set'],
#  'PF00067_PF00067': ['p450', 'p450'],
#  'PF00068_PF00068': ['Phospholip_A2_1', 'Phospholip_A2_1'],
#  'PF00069_PF00027': ['Pkinase', 'cNMP_binding'],
#  'PF00069_PF00041': ['Pkinase', 'fn3'],
#  'PF00069_PF00069': ['Pkinase', 'Pkinase'],
#  'PF00069_PF00071': ['Pkinase', 'Ras'],
#  'PF00069_PF00076': ['Pkinase', 'RRM_1'],
#  'PF00069_PF00096': ['Pkinase', 'zf-C2H2'],
#  'PF00069_PF00240': ['Pkinase', 'ubiquitin'],
#  'PF00069_PF00433': ['Pkinase', 'Pkinase_C'],
#  'PF00069_PF00536': ['Pkinase', 'SAM_1'],
#  'PF00069_PF00539': ['Pkinase', 'Tat'],
#  'PF00069_PF00575': ['Pkinase', 'S1'],
#  'PF00069_PF00581': ['Pkinase', 'Rhodanese'],
#  'PF00069_PF00615': ['Pkinase', 'RGS'],
#  'PF00069_PF00627': ['Pkinase', 'UBA'],
#  'PF00069_PF02026': ['Pkinase', 'RyR'],
#  'PF00069_PF02197': ['Pkinase', 'RIIa'],
#  'PF00069_PF03226': ['Pkinase', 'Yippee-Mis18'],
#  'PF00069_PF03874': ['Pkinase', 'RNA_pol_Rpb4'],
#  'PF00069_PF06479': ['Pkinase', 'Ribonuc_2-5A'],
#  'PF00069_PF07535': ['Pkinase', 'zf-DBF'],
#  'PF00069_PF07686': ['Pkinase', 'V-set'],
#  'PF00069_PF07714': ['Pkinase', 'Pkinase_Tyr'],
#  'PF00069_PF08515': ['Pkinase', 'TGF_beta_GS'],
#  'PF00069_PF08587': ['Pkinase', 'UBA_2'],
#  'PF00069_PF11357': ['Pkinase', 'Spy1'],
#  'PF00069_PF11610': ['Pkinase', 'Ste5'],
#  'PF00069_PF16918': ['Pkinase', 'PknG_TPR'],
#  'PF00069_PF16919': ['Pkinase', 'PknG_rubred'],
#  'PF00069_PF18394': ['Pkinase', 'TBK1_CCD1'],
#  'PF00069_PF18396': ['Pkinase', 'TBK1_ULD'],
#  'PF00071_PF00041': ['Ras', 'fn3'],
#  'PF00071_PF00071': ['Ras', 'Ras'],
#  'PF00071_PF00616': ['Ras', 'RasGAP'],
#  'PF00071_PF00617': ['Ras', 'RasGEF'],
#  'PF00071_PF00618': ['Ras', 'RasGEF_N'],
#  'PF00071_PF00620': ['Ras', 'RhoGAP'],
#  'PF00071_PF00621': ['Ras', 'RhoGEF'],
#  'PF00071_PF00641': ['Ras', 'zf-RanBP'],
#  'PF00071_PF01833': ['Ras', 'TIG'],
#  'PF00071_PF02115': ['Ras', 'Rho_GDI'],
#  'PF00071_PF02204': ['Ras', 'VPS9'],
#  'PF00071_PF03455': ['Ras', 'dDENN'],
#  'PF00071_PF03456': ['Ras', 'uDENN'],
#  'PF00071_PF03545': ['Ras', 'YopE'],
#  'PF00071_PF04099': ['Ras', 'Sybindin'],
#  'PF00071_PF05276': ['Ras', 'SH3BP5'],
#  'PF00071_PF06428': ['Ras', 'Sec2p'],
#  'PF00071_PF07487': ['Ras', 'SopE_GEF'],
#  'PF00071_PF07686': ['Ras', 'V-set'],
#  'PF00071_PF07719': ['Ras', 'TPR_2'],
#  'PF00071_PF08389': ['Ras', 'Xpo1'],
#  'PF00071_PF08912': ['Ras', 'Rho_Binding'],
#  'PF00071_PF11464': ['Ras', 'Rbsn'],
#  'PF00071_PF13181': ['Ras', 'TPR_8'],
#  'PF00071_PF13901': ['Ras', 'zf-RING_9'],
#  'PF00071_PF15277': ['Ras', 'Sec3-PIP2_bind'],
#  'PF00071_PF16845': ['Ras', 'SQAPI'],
#  'PF00072_PF00072': ['Response_reg', 'Response_reg'],
#  'PF00072_PF00158': ['Response_reg', 'Sigma54_activat'],
#  'PF00072_PF00486': ['Response_reg', 'Trans_reg_C'],
#  'PF00072_PF08281': ['Response_reg', 'Sigma70_r4_2'],
#  'PF00072_PF14682': ['Response_reg', 'SPOB_ab'],
#  'PF00072_PF14689': ['Response_reg', 'SPOB_a'],
#  'PF00073_PF00073': ['Rhv', 'Rhv'],
#  'PF00073_PF00084': ['Rhv', 'Sushi'],
#  'PF00073_PF00092': ['Rhv', 'VWA'],
#  'PF00073_PF01822': ['Rhv', 'WSC'],
#  'PF00073_PF07686': ['Rhv', 'V-set'],
#  'PF00073_PF08935': ['Rhv', 'VP4_2'],
#  'PF00074_PF00074': ['RnaseA', 'RnaseA'],
#  'PF00074_PF07686': ['RnaseA', 'V-set'],
#  'PF00075_PF00075': ['RNase_H', 'RNase_H'],
#  'PF00075_PF00078': ['RNase_H', 'RVT_1'],
#  'PF00075_PF03465': ['RNase_H', 'eRF1_3'],
#  'PF00075_PF06815': ['RNase_H', 'RVT_connect'],
#  'PF00075_PF06817': ['RNase_H', 'RVT_thumb'],
#  'PF00076_PF00076': ['RRM_1', 'RRM_1'],
#  'PF00076_PF00085': ['RRM_1', 'Thioredoxin'],
#  'PF00076_PF00164': ['RRM_1', 'Ribosom_S12_S23'],
#  'PF00076_PF00642': ['RRM_1', 'zf-CCCH'],
#  'PF00076_PF01044': ['RRM_1', 'Vinculin'],
#  'PF00076_PF03939': ['RRM_1', 'Ribosomal_L23eN'],
#  'PF00076_PF06487': ['RRM_1', 'SAP18'],
#  'PF00076_PF08080': ['RRM_1', 'zf-RNPHF'],
#  'PF00076_PF08389': ['RRM_1', 'Xpo1'],
#  'PF00076_PF08920': ['RRM_1', 'SF3b1'],
#  'PF00076_PF12220': ['RRM_1', 'U1snRNP70_N'],
#  'PF00076_PF13893': ['RRM_1', 'RRM_5'],
#  'PF00076_PF16131': ['RRM_1', 'Torus'],
#  'PF00076_PF16275': ['RRM_1', 'SF1-HH'],
#  'PF00076_PF16294': ['RRM_1', 'RSB_motif'],
#  'PF00076_PF16842': ['RRM_1', 'RRM_occluded'],
#  'PF00077_PF00077': ['RVP', 'RVP'],
#  'PF00078_PF00078': ['RVT_1', 'RVT_1'],
#  'PF00078_PF06815': ['RVT_1', 'RVT_connect'],
#  'PF00078_PF06817': ['RVT_1', 'RVT_thumb'],
#  'PF00078_PF07686': ['RVT_1', 'V-set'],
#  'PF00078_PF12009': ['RVT_1', 'Telomerase_RBD'],
#  'PF00078_PF13655': ['RVT_1', 'RVT_N'],
#  'PF00078_PF17984': ['RVT_1', 'TERT_thumb'],
#  'PF00079_PF00079': ['Serpin', 'Serpin'],
#  'PF00079_PF00089': ['Serpin', 'Trypsin'],
#  'PF00079_PF01033': ['Serpin', 'Somatomedin_B'],
#  'PF00079_PF07686': ['Serpin', 'V-set'],
#  'PF00080_PF00080': ['Sod_Cu', 'Sod_Cu'],
#  'PF00081_PF00081': ['Sod_Fe_N', 'Sod_Fe_N'],
#  'PF00082_PF00041': ['Peptidase_S8', 'fn3'],
#  'PF00082_PF00082': ['Peptidase_S8', 'Peptidase_S8'],
#  'PF00082_PF00280': ['Peptidase_S8', 'potato_inhibit'],
#  'PF00082_PF00720': ['Peptidase_S8', 'SSI'],
#  'PF00082_PF02428': ['Peptidase_S8', 'Prot_inhib_II'],
#  'PF00082_PF02918': ['Peptidase_S8', 'Pertussis_S2S3'],
#  'PF00082_PF06280': ['Peptidase_S8', 'fn3_5'],
#  'PF00082_PF07686': ['Peptidase_S8', 'V-set'],
#  'PF00082_PF09286': ['Peptidase_S8', 'Pro-kuma_activ'],
#  'PF00082_PF12580': ['Peptidase_S8', 'TPPII'],
#  'PF00082_PF17766': ['Peptidase_S8', 'fn3_6'],
#  'PF00082_PF18213': ['Peptidase_S8', 'SUB1_ProdP9'],
#  'PF00082_PF18237': ['Peptidase_S8', 'Tk-SP_N-pro'],
#  'PF00083_PF00083': ['Sugar_tr', 'Sugar_tr'],
#  'PF00083_PF07686': ['Sugar_tr', 'V-set'],
#  'PF00084_PF00084': ['Sushi', 'Sushi'],
#  'PF00084_PF00089': ['Sushi', 'Trypsin'],
#  'PF00084_PF00092': ['Sushi', 'VWA'],
#  'PF00084_PF07678': ['Sushi', 'TED_complement'],
#  'PF00084_PF07686': ['Sushi', 'V-set'],
#  'PF00084_PF09014': ['Sushi', 'Sushi_2'],
#  'PF00085_PF00085': ['Thioredoxin', 'Thioredoxin'],
#  'PF00085_PF00091': ['Thioredoxin', 'Tubulin'],
#  'PF00085_PF01347': ['Thioredoxin', 'Vitellogenin_N'],
#  'PF00085_PF07686': ['Thioredoxin', 'V-set'],
#  'PF00085_PF13848': ['Thioredoxin', 'Thioredoxin_6'],
#  'PF00086_PF00086': ['Thyroglobulin_1', 'Thyroglobulin_1'],
#  'PF00086_PF00405': ['Thyroglobulin_1', 'Transferrin'],
#  'PF00087_PF00021': ['Toxin_TOLIP', 'UPAR_LY6'],
#  'PF00087_PF00087': ['Toxin_TOLIP', 'Toxin_TOLIP'],
#  'PF00088_PF00088': ['Trefoil', 'Trefoil'],
#  'PF00089_PF00089': ['Trypsin', 'Trypsin'],
#  'PF00089_PF00092': ['Trypsin', 'VWA'],
#  'PF00089_PF00095': ['Trypsin', 'WAP'],
#  'PF00089_PF00280': ['Trypsin', 'potato_inhibit'],
#  'PF00089_PF07686': ['Trypsin', 'V-set'],
#  'PF00090_PF00090': ['TSP_1', 'TSP_1'],
#  'PF00090_PF00092': ['TSP_1', 'VWA'],
#  'PF00090_PF07686': ['TSP_1', 'V-set'],
#  'PF00090_PF18487': ['TSP_1', 'TSR'],
#  'PF00091_PF00091': ['Tubulin', 'Tubulin'],
#  'PF00091_PF03953': ['Tubulin', 'Tubulin_C'],
#  'PF00091_PF14822': ['Tubulin', 'Vasohibin'],
#  'PF00092_PF00092': ['VWA', 'VWA'],
#  'PF00093_PF00093': ['VWC', 'VWC'],
#  'PF00094_PF00094': ['VWD', 'VWD'],
#  'PF00095_PF00095': ['WAP', 'WAP'],
#  'PF00096_PF00096': ['zf-C2H2', 'zf-C2H2'],
#  'PF00096_PF12874': ['zf-C2H2', 'zf-met'],
#  'PF00096_PF13465': ['zf-C2H2', 'zf-H2C2_2'],
#  'PF00096_PF13894': ['zf-C2H2', 'zf-C2H2_4'],
#  'PF00096_PF13909': ['zf-C2H2', 'zf-H2C2_5'],
#  'PF00096_PF18366': ['zf-C2H2', 'zf_ZIC'],
#  'PF00097_PF14835': ['zf-C3HC4', 'zf-RING_6'],
#  'PF00098_PF00098': ['zf-CCHC', 'zf-CCHC'],
#  'PF00100_PF00100': ['Zona_pellucida', 'Zona_pellucida'],
#  'PF00101_PF00101': ['RuBisCO_small', 'RuBisCO_small'],
#  'PF00102_PF00102': ['Y_phosphatase', 'Y_phosphatase'],
#  'PF00102_PF03545': ['Y_phosphatase', 'YopE'],
#  'PF00103_PF00041': ['Hormone_1', 'fn3'],
#  'PF00103_PF00103': ['Hormone_1', 'Hormone_1'],
#  'PF00104_PF00041': ['Hormone_recep', 'fn3'],
#  'PF00104_PF00104': ['Hormone_recep', 'Hormone_recep'],
#  'PF00104_PF00105': ['Hormone_recep', 'zf-C4'],
#  'PF00104_PF08832': ['Hormone_recep', 'SRC-1'],
#  'PF00104_PF13416': ['Hormone_recep', 'SBP_bac_8'],
#  'PF00105_PF00105': ['zf-C4', 'zf-C4'],
#  'PF00106_PF00106': ['adh_short', 'adh_short'],
#  'PF00106_PF13561': ['adh_short', 'adh_short_C2'],
#  'PF00107_PF00107': ['ADH_zinc_N', 'ADH_zinc_N'],
#  'PF00107_PF13602': ['ADH_zinc_N', 'ADH_zinc_N_2'],
#  'PF00107_PF14765': ['ADH_zinc_N', 'PS-DH'],
#  'PF00108_PF00108': ['Thiolase_N', 'Thiolase_N'],
#  'PF00109_PF00109': ['ketoacyl-synt', 'ketoacyl-synt'],
#  'PF00110_PF00110': ['wnt', 'wnt'],
#  'PF00111_PF00067': ['Fer2', 'p450'],
#  'PF00111_PF00111': ['Fer2', 'Fer2'],
#  'PF00111_PF00175': ['Fer2', 'NAD_binding_1'],
#  'PF00111_PF00223': ['Fer2', 'PsaA_PsaB'],
#  'PF00111_PF00355': ['Fer2', 'Rieske'],
#  'PF00111_PF01077': ['Fer2', 'NIR_SIR'],
#  'PF00111_PF01799': ['Fer2', 'Fer2_2'],
#  'PF00111_PF02427': ['Fer2', 'PSI_PsaE'],
#  'PF00111_PF02508': ['Fer2', 'Rnf-Nqr'],
#  'PF00111_PF03460': ['Fer2', 'NIR_SIR_ferr'],
#  'PF00111_PF07992': ['Fer2', 'Pyr_redox_2'],
#  'PF00111_PF12838': ['Fer2', 'Fer4_7'],
#  'PF00111_PF14697': ['Fer2', 'Fer4_21'],
#  'PF00111_PF14759': ['Fer2', 'Reductase_C'],
#  'PF00112_PF00086': ['Peptidase_C1', 'Thyroglobulin_1'],
#  'PF00112_PF00112': ['Peptidase_C1', 'Peptidase_C1'],
#  'PF00112_PF05649': ['Peptidase_C1', 'Peptidase_M13_N'],
#  'PF00112_PF07686': ['Peptidase_C1', 'V-set'],
#  'PF00112_PF08127': ['Peptidase_C1', 'Propeptide_C1'],
#  'PF00112_PF16845': ['Peptidase_C1', 'SQAPI'],
#  'PF00113_PF00113': ['Enolase_C', 'Enolase_C'],
#  'PF00113_PF03952': ['Enolase_C', 'Enolase_N'],
#  'PF00114_PF00114': ['Pilin', 'Pilin'],
#  'PF00114_PF01547': ['Pilin', 'SBP_bac_1'],
#  'PF00114_PF13416': ['Pilin', 'SBP_bac_8'],
#  'PF00115_PF00034': ['COX1', 'Cytochrom_C'],
#  'PF00115_PF00116': ['COX1', 'COX2'],
#  'PF00115_PF00510': ['COX1', 'COX3'],
#  'PF00115_PF01215': ['COX1', 'COX5B'],
#  'PF00115_PF02046': ['COX1', 'COX6A'],
#  'PF00115_PF02238': ['COX1', 'COX7a'],
#  'PF00115_PF02285': ['COX1', 'COX8'],
#  'PF00115_PF02297': ['COX1', 'COX6B'],
#  'PF00115_PF02433': ['COX1', 'FixO'],
#  'PF00115_PF02790': ['COX1', 'COX2_TM'],
#  'PF00115_PF02935': ['COX1', 'COX7C'],
#  'PF00115_PF02936': ['COX1', 'COX4'],
#  'PF00115_PF03626': ['COX1', 'COX4_pro'],
#  'PF00115_PF05392': ['COX1', 'COX7B'],
#  'PF00115_PF06481': ['COX1', 'COX_ARM'],
#  'PF00115_PF07686': ['COX1', 'V-set'],
#  'PF00115_PF07835': ['COX1', 'COX4_pro_2'],
#  'PF00115_PF08113': ['COX1', 'CoxIIa'],
#  'PF00115_PF09125': ['COX1', 'COX2-transmemb'],
#  'PF00115_PF12270': ['COX1', 'Cyt_c_ox_IV'],
#  'PF00115_PF13442': ['COX1', 'Cytochrome_CBB3'],
#  'PF00115_PF14715': ['COX1', 'FixP_N'],
#  'PF00116_PF00034': ['COX2', 'Cytochrom_C'],
#  'PF00116_PF00116': ['COX2', 'COX2'],
#  'PF00116_PF00510': ['COX2', 'COX3'],
#  'PF00116_PF02297': ['COX2', 'COX6B'],
#  'PF00116_PF02790': ['COX2', 'COX2_TM'],
#  'PF00116_PF02936': ['COX2', 'COX4'],
#  'PF00116_PF02937': ['COX2', 'COX6C'],
#  'PF00116_PF06481': ['COX2', 'COX_ARM'],
#  'PF00116_PF07686': ['COX2', 'V-set'],
#  'PF00116_PF07835': ['COX2', 'COX4_pro_2'],
#  'PF00116_PF08113': ['COX2', 'CoxIIa'],
#  'PF00116_PF08534': ['COX2', 'Redoxin'],
#  'PF00116_PF12270': ['COX2', 'Cyt_c_ox_IV'],
#  'PF00116_PF13442': ['COX2', 'Cytochrome_CBB3'],
#  'PF00116_PF18764': ['COX2', 'nos_propeller'],
#  'PF00116_PF18793': ['COX2', 'nos_propeller_2'],
#  'PF00117_PF00117': ['GATase', 'GATase'],
#  'PF00117_PF00958': ['GATase', 'GMP_synt_C'],
#  'PF00117_PF00977': ['GATase', 'His_biosynth'],
#  'PF00117_PF02540': ['GATase', 'NAD_synthase'],
#  'PF00118_PF00118': ['Cpn60_TCP1', 'Cpn60_TCP1'],
#  'PF00118_PF01920': ['Cpn60_TCP1', 'Prefoldin_2'],
#  'PF00118_PF02996': ['Cpn60_TCP1', 'Prefoldin'],
#  'PF00119_PF00119': ['ATP-synt_A', 'ATP-synt_A'],
#  'PF00119_PF00137': ['ATP-synt_A', 'ATP-synt_C'],
#  'PF00119_PF00430': ['ATP-synt_A', 'ATP-synt_B'],
#  'PF00119_PF04911': ['ATP-synt_A', 'ATP-synt_J'],
#  'PF00119_PF05405': ['ATP-synt_A', 'Mt_ATP-synt_B'],
#  'PF00119_PF05873': ['ATP-synt_A', 'Mt_ATP-synt_D'],
#  'PF00119_PF05933': ['ATP-synt_A', 'Fun_ATP-synt_8'],
#  'PF00119_PF08039': ['ATP-synt_A', 'Mit_proteolip'],
#  'PF00119_PF10206': ['ATP-synt_A', 'WRW'],
#  'PF00119_PF10791': ['ATP-synt_A', 'F1F0-ATPsyn_F'],
#  'PF00119_PF11022': ['ATP-synt_A', 'ATP19'],
#  'PF00119_PF14960': ['ATP-synt_A', 'ATP_synth_reg'],
#  'PF00120_PF00120': ['Gln-synt_C', 'Gln-synt_C'],
#  'PF00120_PF03951': ['Gln-synt_C', 'Gln-synt_N'],
#  'PF00120_PF16952': ['Gln-synt_C', 'Gln-synt_N_2'],
#  'PF00120_PF18318': ['Gln-synt_C', 'Gln-synt_C-ter'],
#  'PF00121_PF00121': ['TIM', 'TIM'],
#  'PF00121_PF05690': ['TIM', 'ThiG'],
#  'PF00122_PF00122': ['E1-E2_ATPase', 'E1-E2_ATPase'],
#  'PF00122_PF00403': ['E1-E2_ATPase', 'HMA'],
#  'PF00122_PF00702': ['E1-E2_ATPase', 'Hydrolase'],
#  'PF00122_PF03814': ['E1-E2_ATPase', 'KdpA'],
#  'PF00122_PF08282': ['E1-E2_ATPase', 'Hydrolase_3'],
#  'PF00122_PF09604': ['E1-E2_ATPase', 'Potass_KdpF'],
#  'PF00122_PF16209': ['E1-E2_ATPase', 'PhoLip_ATPase_N'],
#  'PF00122_PF16212': ['E1-E2_ATPase', 'PhoLip_ATPase_C'],
#  'PF00123_PF00123': ['Hormone_2', 'Hormone_2'],
#  'PF00124_PF00124': ['Photo_RC', 'Photo_RC'],
#  'PF00124_PF00737': ['Photo_RC', 'PsbH'],
#  'PF00124_PF01405': ['Photo_RC', 'PsbT'],
#  'PF00124_PF01788': ['Photo_RC', 'PsbJ'],
#  'PF00124_PF01789': ['Photo_RC', 'PsbP'],
#  'PF00124_PF02419': ['Photo_RC', 'PsbL'],
#  'PF00124_PF02532': ['Photo_RC', 'PsbI'],
#  'PF00124_PF05151': ['Photo_RC', 'PsbM'],
#  'PF00124_PF06596': ['Photo_RC', 'PsbX'],
#  'PF00124_PF07123': ['Photo_RC', 'PsbW'],
#  'PF00125_PF00125': ['Histone', 'Histone'],
#  'PF00125_PF00176': ['Histone', 'SNF2_N'],
#  'PF00125_PF00240': ['Histone', 'ubiquitin'],
#  'PF00125_PF00621': ['Histone', 'RhoGEF'],
#  'PF00125_PF00855': ['Histone', 'PWWP'],
#  'PF00125_PF00856': ['Histone', 'SET'],
#  'PF00125_PF00956': ['Histone', 'NAP'],
#  'PF00125_PF03281': ['Histone', 'Mab-21'],
#  'PF00125_PF03810': ['Histone', 'IBN_N'],
#  'PF00125_PF04563': ['Histone', 'RNA_pol_Rpb2_1'],
#  'PF00125_PF04855': ['Histone', 'SNF5'],
#  'PF00125_PF05764': ['Histone', 'YL1'],
#  'PF00125_PF07686': ['Histone', 'V-set'],
#  'PF00125_PF08209': ['Histone', 'Sgf11'],
#  'PF00125_PF08243': ['Histone', 'SPT2'],
#  'PF00125_PF08512': ['Histone', 'Rtt106'],
#  'PF00125_PF10384': ['Histone', 'Scm3'],
#  'PF00125_PF11764': ['Histone', 'N-SET'],
#  'PF00125_PF12619': ['Histone', 'MCM2_N'],
#  'PF00125_PF13923': ['Histone', 'zf-C3HC4_2'],
#  'PF00125_PF16211': ['Histone', 'Histone_H2A_C'],
#  'PF00125_PF18264': ['Histone', 'preSET_CXC'],
#  'PF00126_PF00126': ['HTH_1', 'HTH_1'],
#  'PF00126_PF03466': ['HTH_1', 'LysR_substrate'],
#  'PF00127_PF00127': ['Copper-bind', 'Copper-bind'],
#  'PF00127_PF00223': ['Copper-bind', 'PsaA_PsaB'],
#  'PF00127_PF00394': ['Copper-bind', 'Cu-oxidase'],
#  'PF00127_PF02975': ['Copper-bind', 'Me-amine-dh_L'],
#  'PF00127_PF06433': ['Copper-bind', 'Me-amine-dh_H'],
#  'PF00127_PF07732': ['Copper-bind', 'Cu-oxidase_3'],
#  'PF00127_PF13442': ['Copper-bind', 'Cytochrome_CBB3'],
#  'PF00128_PF00128': ['Alpha-amylase', 'Alpha-amylase'],
#  'PF00128_PF00139': ['Alpha-amylase', 'Lectin_legB'],
#  'PF00128_PF00197': ['Alpha-amylase', 'Kunitz_legume'],
#  'PF00128_PF00234': ['Alpha-amylase', 'Tryp_alpha_amyl'],
#  'PF00128_PF00686': ['Alpha-amylase', 'CBM_20'],
#  'PF00128_PF01833': ['Alpha-amylase', 'TIG'],
#  'PF00128_PF02806': ['Alpha-amylase', 'Alpha-amylase_C'],
#  'PF00128_PF02903': ['Alpha-amylase', 'Alpha-amylase_N'],
#  'PF00128_PF02922': ['Alpha-amylase', 'CBM_48'],
#  'PF00128_PF03714': ['Alpha-amylase', 'PUD'],
#  'PF00128_PF07686': ['Alpha-amylase', 'V-set'],
#  'PF00128_PF09081': ['Alpha-amylase', 'DUF1921'],
#  'PF00128_PF09087': ['Alpha-amylase', 'Cyc-maltodext_N'],
#  'PF00128_PF09154': ['Alpha-amylase', 'DUF1939'],
#  'PF00128_PF09178': ['Alpha-amylase', 'DUF1945'],
#  'PF00128_PF09196': ['Alpha-amylase', 'DUF1953'],
#  'PF00128_PF09244': ['Alpha-amylase', 'DUF1964'],
#  'PF00128_PF09260': ['Alpha-amylase', 'DUF1966'],
#  'PF00128_PF10438': ['Alpha-amylase', 'Cyc-maltodext_C'],
#  'PF00128_PF11896': ['Alpha-amylase', 'DUF3416'],
#  'PF00128_PF11941': ['Alpha-amylase', 'DUF3459'],
#  'PF00128_PF16028': ['Alpha-amylase', 'SLC3A2_N'],
#  'PF00128_PF16657': ['Alpha-amylase', 'Malt_amylase_C'],
#  'PF00128_PF17999': ['Alpha-amylase', 'PulA_N1'],
#  'PF00128_PF18033': ['Alpha-amylase', 'SpuA_C'],
#  'PF00128_PF18612': ['Alpha-amylase', 'Bac_A_amyl_C'],
#  'PF00129_PF00047': ['MHC_I', 'ig'],
#  'PF00129_PF00073': ['MHC_I', 'Rhv'],
#  'PF00129_PF00129': ['MHC_I', 'MHC_I'],
#  'PF00129_PF00273': ['MHC_I', 'Serum_albumin'],
#  'PF00129_PF04253': ['MHC_I', 'TFR_dimer'],
#  'PF00129_PF04490': ['MHC_I', 'Pox_T4_C'],
#  'PF00129_PF05326': ['MHC_I', 'SVA'],
#  'PF00129_PF07686': ['MHC_I', 'V-set'],
#  'PF00129_PF17622': ['MHC_I', 'UL16'],
#  'PF00130_PF00017': ['C1_1', 'SH2'],
#  'PF00130_PF00069': ['C1_1', 'Pkinase'],
#  'PF00130_PF00071': ['C1_1', 'Ras'],
#  'PF00130_PF00130': ['C1_1', 'C1_1'],
#  'PF00130_PF00168': ['C1_1', 'C2'],
#  'PF00130_PF00169': ['C1_1', 'PH'],
#  'PF00130_PF00621': ['C1_1', 'RhoGEF'],
#  'PF00130_PF02196': ['C1_1', 'RBD'],
#  'PF00130_PF07714': ['C1_1', 'Pkinase_Tyr'],
#  'PF00132_PF00132': ['Hexapep', 'Hexapep'],
#  'PF00132_PF00483': ['Hexapep', 'NTP_transferase'],
#  'PF00132_PF01008': ['Hexapep', 'IF-2B'],
#  'PF00132_PF04613': ['Hexapep', 'LpxD'],
#  'PF00132_PF06426': ['Hexapep', 'SATase_N'],
#  'PF00132_PF12804': ['Hexapep', 'NTP_transf_3'],
#  'PF00132_PF14602': ['Hexapep', 'Hexapep_2'],
#  'PF00132_PF14805': ['Hexapep', 'THDPS_N_2'],
#  'PF00132_PF17836': ['Hexapep', 'PglD_N'],
#  'PF00133_PF00133': ['tRNA-synt_1', 'tRNA-synt_1'],
#  'PF00133_PF09334': ['tRNA-synt_1', 'tRNA-synt_1g'],
#  'PF00133_PF13603': ['tRNA-synt_1', 'tRNA-synt_1_2'],
#  'PF00134_PF00069': ['Cyclin_N', 'Pkinase'],
#  'PF00134_PF00134': ['Cyclin_N', 'Cyclin_N'],
#  'PF00134_PF00539': ['Cyclin_N', 'Tat'],
#  'PF00134_PF09080': ['Cyclin_N', 'K-cyclin_vir_C'],
#  'PF00134_PF09241': ['Cyclin_N', 'Herp-Cyclin'],
#  'PF00135_PF00086': ['COesterase', 'Thyroglobulin_1'],
#  'PF00135_PF00135': ['COesterase', 'COesterase'],
#  'PF00135_PF02210': ['COesterase', 'Laminin_G_2'],
#  'PF00135_PF07686': ['COesterase', 'V-set'],
#  'PF00135_PF13927': ['COesterase', 'Ig_3'],
#  'PF00136_PF00136': ['DNA_pol_B', 'DNA_pol_B'],
#  'PF00136_PF00705': ['DNA_pol_B', 'PCNA_N'],
#  'PF00136_PF03104': ['DNA_pol_B', 'DNA_pol_B_exo1'],
#  'PF00136_PF04104': ['DNA_pol_B', 'DNA_primase_lrg'],
#  'PF00136_PF08408': ['DNA_pol_B', 'DNA_pol_B_3'],
#  'PF00136_PF08996': ['DNA_pol_B', 'zf-DNA_Pol'],
#  'PF00136_PF14260': ['DNA_pol_B', 'zf-C4pol'],
#  'PF00137_PF00137': ['ATP-synt_C', 'ATP-synt_C'],
#  'PF00137_PF01496': ['ATP-synt_C', 'V_ATPase_I'],
#  'PF00137_PF01992': ['ATP-synt_C', 'vATP-synt_AC39'],
#  'PF00137_PF02823': ['ATP-synt_C', 'ATP-synt_DE_N'],
#  'PF00137_PF03223': ['ATP-synt_C', 'V-ATPase_C'],
#  'PF00137_PF05827': ['ATP-synt_C', 'ATP-synt_S1'],
#  'PF00137_PF07850': ['ATP-synt_C', 'Renin_r'],
#  'PF00139_PF00139': ['Lectin_legB', 'Lectin_legB'],
#  'PF00139_PF00405': ['Lectin_legB', 'Transferrin'],
#  'PF00140_PF04539': ['Sigma70_r1_2', 'Sigma70_r3'],
#  'PF00140_PF04542': ['Sigma70_r1_2', 'Sigma70_r2'],
#  'PF00141_PF00141': ['peroxidase', 'peroxidase'],
#  'PF00142_PF00142': ['Fer4_NifH', 'Fer4_NifH'],
#  'PF00142_PF00148': ['Fer4_NifH', 'Oxidored_nitro'],
#  'PF00143_PF00047': ['Interferon', 'ig'],
#  'PF00143_PF00143': ['Interferon', 'Interferon'],
#  'PF00143_PF01108': ['Interferon', 'Tissue_fac'],
#  'PF00143_PF07686': ['Interferon', 'V-set'],
#  'PF00144_PF00144': ['Beta-lactamase', 'Beta-lactamase'],
#  'PF00144_PF07930': ['Beta-lactamase', 'DAP_B'],
#  'PF00144_PF13969': ['Beta-lactamase', 'Pab87_oct'],
#  'PF00145_PF00145': ['DNA_methylase', 'DNA_methylase'],
#  'PF00145_PF02008': ['DNA_methylase', 'zf-CXXC'],
#  'PF00145_PF12047': ['DNA_methylase', 'DNMT1-RFD'],
#  'PF00145_PF12436': ['DNA_methylase', 'USP7_ICP0_bdg'],
#  'PF00145_PF14533': ['DNA_methylase', 'USP7_C2'],
#  'PF00146_PF00146': ['NADHdh', 'NADHdh'],
#  'PF00146_PF00361': ['NADHdh', 'Proton_antipo_M'],
#  'PF00146_PF00499': ['NADHdh', 'Oxidored_q3'],
#  'PF00146_PF00507': ['NADHdh', 'Oxidored_q4'],
#  'PF00146_PF01058': ['NADHdh', 'Oxidored_q6'],
#  'PF00146_PF10716': ['NADHdh', 'NdhL'],
#  'PF00146_PF14987': ['NADHdh', 'NADHdh_A3'],
#  'PF00147_PF00147': ['Fibrinogen_C', 'Fibrinogen_C'],
#  'PF00147_PF07686': ['Fibrinogen_C', 'V-set'],
#  'PF00148_PF00148': ['Oxidored_nitro', 'Oxidored_nitro'],
#  'PF00148_PF08369': ['Oxidored_nitro', 'PCP_red'],
#  'PF00149_PF00149': ['Metallophos', 'Metallophos'],
#  'PF00149_PF00160': ['Metallophos', 'Pro_isomerase'],
#  'PF00149_PF00515': ['Metallophos', 'TPR_1'],
#  'PF00149_PF00595': ['Metallophos', 'PDZ'],
#  'PF00149_PF03095': ['Metallophos', 'PTPA'],
#  'PF00149_PF04152': ['Metallophos', 'Mre11_DNA_bind'],
#  'PF00149_PF04176': ['Metallophos', 'TIP41'],
#  'PF00149_PF04177': ['Metallophos', 'TAP42'],
#  'PF00149_PF07686': ['Metallophos', 'V-set'],
#  'PF00149_PF08321': ['Metallophos', 'PPP5'],
#  'PF00149_PF10488': ['Metallophos', 'PP1c_bdg'],
#  'PF00149_PF12320': ['Metallophos', 'SbcD_C'],
#  'PF00149_PF13431': ['Metallophos', 'TPR_17'],
#  'PF00149_PF13519': ['Metallophos', 'VWA_2'],
#  'PF00149_PF13558': ['Metallophos', 'SbcCD_C'],
#  'PF00149_PF14008': ['Metallophos', 'Metallophos_C'],
#  'PF00149_PF15276': ['Metallophos', 'PP1_bind'],
#  'PF00149_PF16656': ['Metallophos', 'Pur_ac_phosph_N'],
#  'PF00149_PF16891': ['Metallophos', 'STPPase_N'],
#  'PF00149_PF17808': ['Metallophos', 'fn3_PAP'],
#  'PF00149_PF17817': ['Metallophos', 'PDZ_5'],
#  'PF00150_PF00150': ['Cellulase', 'Cellulase'],
#  'PF00150_PF02156': ['Cellulase', 'Glyco_hydro_26'],
#  'PF00150_PF18564': ['Cellulase', 'Glyco_hydro_5_C'],
#  'PF00151_PF00151': ['Lipase', 'Lipase'],
#  'PF00151_PF01477': ['Lipase', 'PLAT'],
#  'PF00152_PF00152': ['tRNA-synt_2', 'tRNA-synt_2'],
#  'PF00152_PF01336': ['tRNA-synt_2', 'tRNA_anti-codon'],
#  'PF00153_PF00153': ['Mito_carr', 'Mito_carr'],
#  'PF00153_PF07686': ['Mito_carr', 'V-set'],
#  'PF00154_PF00154': ['RecA', 'RecA'],
#  'PF00155_PF00155': ['Aminotran_1_2', 'Aminotran_1_2'],
#  'PF00155_PF00392': ['Aminotran_1_2', 'GntR'],
#  'PF00156_PF00156': ['Pribosyltran', 'Pribosyltran'],
#  'PF00156_PF09182': ['Pribosyltran', 'PuR_N'],
#  'PF00156_PF13793': ['Pribosyltran', 'Pribosyltran_N'],
#  'PF00157_PF00157': ['Pou', 'Pou'],
#  'PF00158_PF00158': ['Sigma54_activat', 'Sigma54_activat'],
#  'PF00158_PF02830': ['Sigma54_activat', 'V4R'],
#  'PF00158_PF06505': ['Sigma54_activat', 'XylR_N'],
#  'PF00159_PF00071': ['Hormone_3', 'Ras'],
#  'PF00159_PF00159': ['Hormone_3', 'Hormone_3'],
#  'PF00160_PF00076': ['Pro_isomerase', 'RRM_1'],
#  'PF00160_PF00160': ['Pro_isomerase', 'Pro_isomerase'],
#  'PF00161_PF00161': ['RIP', 'RIP'],
#  'PF00161_PF00652': ['RIP', 'Ricin_B_lectin'],
#  'PF00161_PF02258': ['RIP', 'SLT_beta'],
#  'PF00161_PF07686': ['RIP', 'V-set'],
#  'PF00162_PF00162': ['PGK', 'PGK'],
#  'PF00163_PF00410': ['Ribosomal_S4', 'Ribosomal_S8'],
#  'PF00163_PF01479': ['Ribosomal_S4', 'S4'],
#  'PF00163_PF03719': ['Ribosomal_S4', 'Ribosomal_S5_C'],
#  'PF00164_PF01176': ['Ribosom_S12_S23', 'eIF-1a'],
#  'PF00164_PF01668': ['Ribosom_S12_S23', 'SmpB'],
#  'PF00164_PF03464': ['Ribosom_S12_S23', 'eRF1_2'],
#  'PF00164_PF04758': ['Ribosom_S12_S23', 'Ribosomal_S30'],
#  'PF00164_PF06769': ['Ribosom_S12_S23', 'YoeB_toxin'],
#  'PF00164_PF08597': ['Ribosom_S12_S23', 'eIF3_subunit'],
#  'PF00164_PF09202': ['Ribosom_S12_S23', 'Rio2_N'],
#  'PF00166_PF00118': ['Cpn10', 'Cpn60_TCP1'],
#  'PF00166_PF00166': ['Cpn10', 'Cpn10'],
#  'PF00167_PF00167': ['FGF', 'FGF'],
#  'PF00167_PF01023': ['FGF', 'S_100'],
#  'PF00167_PF07679': ['FGF', 'I-set'],
#  'PF00167_PF07686': ['FGF', 'V-set'],
#  'PF00167_PF13927': ['FGF', 'Ig_3'],
#  'PF00168_PF00017': ['C2', 'SH2'],
#  'PF00168_PF00167': ['C2', 'FGF'],
#  'PF00168_PF00168': ['C2', 'C2'],
#  'PF00168_PF00387': ['C2', 'PI-PLC-Y'],
#  'PF00168_PF00388': ['C2', 'PI-PLC-X'],
#  'PF00168_PF00804': ['C2', 'Syntaxin'],
#  'PF00168_PF01023': ['C2', 'S_100'],
#  'PF00168_PF01735': ['C2', 'PLA2_B'],
#  'PF00168_PF05739': ['C2', 'SNARE'],
#  'PF00168_PF05835': ['C2', 'Synaphin'],
#  'PF00168_PF07002': ['C2', 'Copine'],
#  'PF00168_PF09279': ['C2', 'EF-hand_like'],
#  'PF00168_PF17047': ['C2', 'SMP_LBD'],
#  'PF00168_PF18695': ['C2', 'cPLA2_C2'],
#  'PF00169_PF00018': ['PH', 'SH3_1'],
#  'PF00169_PF00069': ['PH', 'Pkinase'],
#  'PF00169_PF00071': ['PH', 'Ras'],
#  'PF00169_PF00169': ['PH', 'PH'],
#  'PF00169_PF00400': ['PH', 'WD40'],
#  'PF00169_PF00621': ['PH', 'RhoGEF'],
#  'PF00169_PF00787': ['PH', 'PX'],
#  'PF00169_PF00788': ['PH', 'RA'],
#  'PF00169_PF01369': ['PH', 'Sec7'],
#  'PF00169_PF01852': ['PH', 'START'],
#  'PF00169_PF06767': ['PH', 'Sif'],
#  'PF00169_PF07714': ['PH', 'Pkinase_Tyr'],
#  'PF00169_PF18385': ['PH', 'Tiam_CC_Ex'],
#  'PF00170_PF00170': ['bZIP_1', 'bZIP_1'],
#  'PF00170_PF03131': ['bZIP_1', 'bZIP_Maf'],
#  'PF00170_PF07716': ['bZIP_1', 'bZIP_2'],
#  'PF00171_PF00171': ['Aldedh', 'Aldedh'],
#  'PF00171_PF00465': ['Aldedh', 'Fe-ADH'],
#  'PF00171_PF01575': ['Aldedh', 'MaoC_dehydratas'],
#  ...}

# %%
# ProtCID files were received from the authors; there is one file for each domain combination that has
# at least one cluster
# Files were named in the way (ShortName Domain1)(ShortName Domain2)_xxxx.txt.gz
# Processing steps:
# Unzip the gzipped files in the source directory (dir_name) into another directory (dir1_name)

dir_name = '/Users/johgeist/Documents/AG_Luck/Project_Thesis/Files/ProtCID/DomainClusterData_20211020/'
dir1_name = '/Users/johgeist/Documents/AG_Luck/Project_Thesis/Files/ProtCID/DomainClusterData_20211020_unzipped/'


def decompress(infile, tofile):
    with open(infile, 'rb') as inf, open(tofile, 'w', encoding='utf8') as tof:
        decom_str = gzip.decompress(inf.read()).decode('utf-8')
        tof.write(decom_str)
        
#for infile in glob.glob(dir_name + '*.gz'):
    #tofile = dir1_name + '/' + infile.split('/')[-1][:-3]
    #print(tofile)
    #decompress(infile, tofile)

# %%
# ProtCID files contain a table-like structure that has a summary row before each cluster containing the surface 
# area and metrics from the individual 3d structures in one cluster
# Followed by that summarizing row there are rows referring to a single 3D structure within the cluster.
# Parse the ProtCID files and generate a DataFrame that stores all relevant information for each cluster of a DDI
# type.
# Make two temporary dataframes (one of the summarizing row and one grouping the single 3D structures of one 
# cluster together, that were joined to the final df_joined after dropping unnecessary information. 
# Add additional columns that save the domain names, the file name, the ClusterID and the DDI type from
# the dictionary I created before.
file = '/Users/johgeist/Documents/AG_Luck/Project_Thesis/Files/ProtCID/DomainClusterData_20211020_unzipped/(Adenine_deam_C)(Amidohydro_1)_1471.txt'
domain_names = re.findall(r'\((.*?)\)', file)
df = pd.read_csv(file, index_col=False, sep='\t', low_memory=False)
temp = df.drop_duplicates(subset='ClusterID',keep='first')
temp = temp.drop(labels = ['Relation', 'CFID', 'SpaceGroup', 'CrystForm', 'PdbID', 'DomainInterfaceID',
                           'InterfaceUnit', 'ChainPfamArch', 'InAsu', 'InPdb', 'InPisa', 'ASU', 'PDBBA',
                           'PDBBAID', 'PISABA', 'PISABAID', 'UnpCode', 'Name', 'Species', '#CfgRelation',
                           '#EntryRelation' , '#CfgCluster','#EntryCluster', '#EntryHomo', '#EntryHetero',
                           '#EntryIntra', 'ClusterInterface'], axis=1)
temp = temp[temp['ClusterID'].apply(lambda x: str(x).isdigit())]
temp_1 = df.dropna(subset=['CFID']).groupby('ClusterID').agg({'PdbID':lambda x: ','.join(set([i for i in x if type(i) == str])),
                        #'ChainPfamArch':lambda x: ','.join(set([i for i in x if type(i) == str])),
                        'UnpCode':lambda x: ','.join(set([i for i in x if type(i) == str])),
                        'Species':lambda x: ','.join(set([i for i in x if type(i) == str])), 
                        #'CrystForm':lambda x: ','.join(set([i for i in x if type(i) == str])),
                        'CFID': lambda x: ','.join(set([str(i) for i in x if type(i) == float]))})
#temp_1.reset_index(inplace = True)
#temp_1.set_index('ClusterID', inplace = True)
#temp.reset_index(inplace = True)
temp.set_index('ClusterID', inplace= True)
df_joined = temp.join(temp_1, on='ClusterID', how='left')
# #df_joined['DDI_type'] = DDI_type_domainIDs.get(':'.join(domain_names), np.nan)
df_joined.reset_index(inplace= True)
for DDI_type, IDs in DDI_type_domainIDs.items():
    if len(domain_names) == 1:
        if (domain_names[0] == IDs[0]) and (domain_names[0] == IDs[1]):
            df_joined.insert(0, 'DDI_type', DDI_type)   
    elif len(domain_names) > 1:   
        if (domain_names[0] in IDs) and (domain_names[1] in IDs):
            df_joined.insert(0, 'DDI_type', DDI_type)
df_joined.insert(0, 'DomainNames', ' '.join(domain_names))
df_joined.insert(1, 'FileName', file.split('/')[-1])



for file in glob.glob(dir1_name + '*.txt'):
    if file == '/Users/johgeist/Documents/AG_Luck/Project_Thesis/Files/ProtCID/DomainClusterData_20211020_unzipped/(Adenine_deam_C)(Amidohydro_1)_1471.txt':
        pass
    else:
        df_joined = df_joined.copy(deep= True)
        domain_names = re.findall(r'\((.*?)\)', file)
        
        df = pd.read_csv(file, index_col=False, sep='\t', low_memory=False)
        temp = df.drop_duplicates(subset='ClusterID',keep='first')
        temp = temp.drop(labels = ['Relation', 'CFID', 'SpaceGroup', 'CrystForm', 'PdbID', 'DomainInterfaceID',
                                   'InterfaceUnit', 'ChainPfamArch', 'InAsu', 'InPdb', 'InPisa', 'ASU', 'PDBBA',
                                   'PDBBAID', 'PISABA', 'PISABAID', 'UnpCode', 'Name', 'Species', '#CfgRelation',
                                   '#EntryRelation' , '#CfgCluster','#EntryCluster', '#EntryHomo', '#EntryHetero',
                                   '#EntryIntra', 'ClusterInterface'], axis=1)
        temp = temp[temp['ClusterID'].apply(lambda x: str(x).isdigit())]
        temp_1 = df.dropna(subset=['CFID']).groupby('ClusterID').agg({'PdbID':lambda x: ','.join(set([i for i in x if type(i) == str])),
                                #'ChainPfamArch':lambda x: ','.join(set([i for i in x if type(i) == str])),
                                'UnpCode':lambda x: ','.join(set([i for i in x if type(i) == str])),
                                'Species':lambda x: ','.join(set([i for i in x if type(i) == str])),
                                #'CrystForm':lambda x: ','.join(set([i for i in x if type(i) == str])),
                                'CFID': lambda x: ','.join(set([str(i) for i in x if type(i) == float]))})
        #temp_1.reset_index(inplace = True)
        #temp_1.set_index('ClusterID', inplace = True)
        #temp.reset_index(inplace = True)
        temp.set_index('ClusterID', inplace= True)
        df_joined1 = temp.join(temp_1, on='ClusterID', how='left' )
        #df_joined1['DDI_type'] = DDI_type_domainIDs.get(':'.join(domain_names), np.nan)
        df_joined1.reset_index(inplace= True)
        for DDI_type, IDs in DDI_type_domainIDs.items():
            if len(domain_names) == 1:
                if (domain_names[0] == IDs[0]) and (domain_names[0] == IDs[1]):
                    df_joined1['DDI_type'] = DDI_type
            elif len(domain_names) > 1:   
                if (domain_names[0] in IDs) and (domain_names[1] in IDs):
                    df_joined1['DDI_type'] = DDI_type
        df_joined1.insert(0, 'DomainNames', ' '.join(domain_names))
        df_joined1.insert(1, 'FileName', file.split('/')[-1])
        df_joined= pd.concat([df_joined,df_joined1], ignore_index = True)

# %%
df_joined
# Out:
#                        DomainNames                                 FileName
# 0      Adenine_deam_C Amidohydro_1  (Adenine_deam_C)(Amidohydro_1)_1471.txt  \
# 1      Adenine_deam_C Amidohydro_1  (Adenine_deam_C)(Amidohydro_1)_1471.txt
# 2      Adenine_deam_C Amidohydro_1  (Adenine_deam_C)(Amidohydro_1)_1471.txt
# 3                       Med21 Med4                  (Med21)(Med4)_19935.txt
# 4                    Synaptobrevin                (Synaptobrevin)_17022.txt
# ...                            ...                                      ...
# 64561                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
# 64562                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
# 64563                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
# 64564                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
# 64565                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
#
#               DDI_type ClusterID  SurfaceArea  MinSeqIdentity
# 0      PF13382_PF01979         1    1622.5920            78.0  \
# 1      PF13382_PF01979         2     366.8667            78.0
# 2      PF13382_PF01979         3     159.1500            78.0
# 3      PF11221_PF10018         1     481.3500            27.0
# 4      PF00957_PF00957         1     348.0500           100.0
# ...                ...       ...          ...             ...
# 64561  PF10417_PF10417         4     181.0100            64.0
# 64562  PF10417_PF10417         5     351.3625            48.0
# 64563  PF10417_PF10417         6     130.6750            48.0
# 64564  PF10417_PF10417         7     179.2750            55.0
# 64565  PF10417_PF10417         8     167.5000           100.0
#
#        MediumSurfaceArea           PdbID
# 0                1660.35  3t8l,3t81,3nqb  \
# 1                 380.60  3t8l,3t81,3nqb
# 2                 163.85  3t8l,3t81,3nqb
# 3                 506.75       5oqm,5n9j
# 4                 366.90       6wvw,1sfc
# ...                  ...             ...
# 64561             214.55  2v41,5b6n,5b6m
# 64562             396.80  3sbc,5jcg,5ucx
# 64563             133.70       4k1f,2i81
# 64564             249.65       4k1f,2z9s
# 64565             167.05       2v32,2v2g
#
#                                              UnpCode
# 0                            ADEC2_AGRFC;ADEC2_AGRFC  \
# 1                            ADEC2_AGRFC;ADEC2_AGRFC
# 2                            ADEC2_AGRFC;ADEC2_AGRFC
# 3      MED21_SCHPO;MED4_SCHPO,MED21_YEAST;MED4_YEAST
# 4                                          VAMP2_RAT
# ...                                              ...
# 64561                       Q1AN22_AREMA,PRDX6_HUMAN
# 64562                         TSA1_YEAST,PRDX3_HUMAN
# 64563                      A5K421_PLAVS,Q4QF76_LEIMA
# 64564                         PRDX1_RAT,Q4QF76_LEIMA
# 64565                                   Q1AN22_AREMA
#
#                                                  Species       CFID
# 0      Agrobacterium tumefaciens;Agrobacterium tumefa...        1.0
# 1      Agrobacterium tumefaciens;Agrobacterium tumefa...        1.0
# 2      Agrobacterium tumefaciens;Agrobacterium tumefa...        1.0
# 3      Saccharomyces cerevisiae (strain ATCC 204508 /...    2.0,6.0
# 4                                      Rattus norvegicus    8.0,5.0
# ...                                                  ...        ...
# 64561                      Homo sapiens,ARENICOLA MARINA   9.0,30.0
# 64562              Homo sapiens,Saccharomyces cerevisiae   18.0,5.0
# 64563            Leishmania major,Plasmodium vivax SaI-1  16.0,15.0
# 64564                 Leishmania major,Rattus norvegicus  16.0,24.0
# 64565                                   ARENICOLA MARINA        8.0
#
# [64566 rows x 11 columns]

# %%
# In df_joined the ClusterIDs were provided by the ProtCID files partly as string -> change the data type of 
# the column to integers
df_joined['ClusterID'] = pd.to_numeric(df_joined['ClusterID'])

# %%
df_joined
# Out:
#                        DomainNames                                 FileName
# 0      Adenine_deam_C Amidohydro_1  (Adenine_deam_C)(Amidohydro_1)_1471.txt  \
# 1      Adenine_deam_C Amidohydro_1  (Adenine_deam_C)(Amidohydro_1)_1471.txt
# 2      Adenine_deam_C Amidohydro_1  (Adenine_deam_C)(Amidohydro_1)_1471.txt
# 3                       Med21 Med4                  (Med21)(Med4)_19935.txt
# 4                    Synaptobrevin                (Synaptobrevin)_17022.txt
# ...                            ...                                      ...
# 64561                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
# 64562                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
# 64563                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
# 64564                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
# 64565                   1-cysPrx_C                       (1-cysPrx_C)_1.txt
#
#               DDI_type  ClusterID  SurfaceArea  MinSeqIdentity
# 0      PF13382_PF01979          1    1622.5920            78.0  \
# 1      PF13382_PF01979          2     366.8667            78.0
# 2      PF13382_PF01979          3     159.1500            78.0
# 3      PF11221_PF10018          1     481.3500            27.0
# 4      PF00957_PF00957          1     348.0500           100.0
# ...                ...        ...          ...             ...
# 64561  PF10417_PF10417          4     181.0100            64.0
# 64562  PF10417_PF10417          5     351.3625            48.0
# 64563  PF10417_PF10417          6     130.6750            48.0
# 64564  PF10417_PF10417          7     179.2750            55.0
# 64565  PF10417_PF10417          8     167.5000           100.0
#
#        MediumSurfaceArea           PdbID
# 0                1660.35  3t8l,3t81,3nqb  \
# 1                 380.60  3t8l,3t81,3nqb
# 2                 163.85  3t8l,3t81,3nqb
# 3                 506.75       5oqm,5n9j
# 4                 366.90       6wvw,1sfc
# ...                  ...             ...
# 64561             214.55  2v41,5b6n,5b6m
# 64562             396.80  3sbc,5jcg,5ucx
# 64563             133.70       4k1f,2i81
# 64564             249.65       4k1f,2z9s
# 64565             167.05       2v32,2v2g
#
#                                              UnpCode
# 0                            ADEC2_AGRFC;ADEC2_AGRFC  \
# 1                            ADEC2_AGRFC;ADEC2_AGRFC
# 2                            ADEC2_AGRFC;ADEC2_AGRFC
# 3      MED21_SCHPO;MED4_SCHPO,MED21_YEAST;MED4_YEAST
# 4                                          VAMP2_RAT
# ...                                              ...
# 64561                       Q1AN22_AREMA,PRDX6_HUMAN
# 64562                         TSA1_YEAST,PRDX3_HUMAN
# 64563                      A5K421_PLAVS,Q4QF76_LEIMA
# 64564                         PRDX1_RAT,Q4QF76_LEIMA
# 64565                                   Q1AN22_AREMA
#
#                                                  Species       CFID
# 0      Agrobacterium tumefaciens;Agrobacterium tumefa...        1.0
# 1      Agrobacterium tumefaciens;Agrobacterium tumefa...        1.0
# 2      Agrobacterium tumefaciens;Agrobacterium tumefa...        1.0
# 3      Saccharomyces cerevisiae (strain ATCC 204508 /...    2.0,6.0
# 4                                      Rattus norvegicus    8.0,5.0
# ...                                                  ...        ...
# 64561                      Homo sapiens,ARENICOLA MARINA   9.0,30.0
# 64562              Homo sapiens,Saccharomyces cerevisiae   18.0,5.0
# 64563            Leishmania major,Plasmodium vivax SaI-1  16.0,15.0
# 64564                 Leishmania major,Rattus norvegicus  16.0,24.0
# 64565                                   ARENICOLA MARINA        8.0
#
# [64566 rows x 11 columns]

# %%
#df_joined.to_csv('/Users/johannageist/Documents/AG_Luck/Projektarbeit/Files/ProtCID/Master_Dataframe_ProtCID/master_df_ProtCID_20220201.csv', index= False, sep= '\t')

# %%
# Read in the previously generated 3did subset holding only those DDI types with at least one heterodimeric
# structure and one interchain interface as a DataFrame
df_inter_hetero = pd.read_csv('/Users/johgeist/Downloads/3did_project_dataframes_new/3did_metrics_inter_hetero_subset.csv', index_col=0)

# %%
df_inter_hetero
# Out:
#                 DomainID1 DomainID2     DomainName1   DomainName2
# DDI_type
# PF00001_PF00048   PF00001   PF00048           7tm_1           IL8  \
# PF00001_PF00085   PF00001   PF00085           7tm_1   Thioredoxin
# PF00001_PF00087   PF00001   PF00087           7tm_1   Toxin_TOLIP
# PF00001_PF00322   PF00001   PF00322           7tm_1    Endothelin
# PF00001_PF00339   PF00001   PF00339           7tm_1    Arrestin_N
# ...                   ...       ...             ...           ...
# PF18782_PF00559   PF18782   PF00559            NAD2           Vif
# PF18784_PF00071   PF18784   PF00071   CRM1_repeat_2           Ras
# PF18801_PF00072   PF18801   PF00072          RapH_N  Response_reg
# PF18806_PF00071   PF18806   PF00071  Importin_rep_3           Ras
# PF18808_PF00071   PF18808   PF00071  Importin_rep_4           Ras
#
#                  Num_structures  Num_interchain_structures  Score    Zscore
# DDI_type
# PF00001_PF00048               8                          8  13.26  5.101720  \
# PF00001_PF00085               7                          6   1.57  1.963520
# PF00001_PF00087               1                          1  15.76  5.828060
# PF00001_PF00322               4                          4  31.19  7.365980
# PF00001_PF00339               6                          3  18.24  5.657100
# ...                         ...                        ...    ...       ...
# PF18782_PF00559               1                          1   7.74  3.639300
# PF18784_PF00071              34                         34   8.76  4.306780
# PF18801_PF00072               1                          1  10.48  4.961570
# PF18806_PF00071               1                          1   0.05  0.237612
# PF18808_PF00071               1                          1   4.23  2.982020
#
#                  contacts1 PDB_ID_max  Interchain_fraction
# DDI_type
# PF00001_PF00048         51       5UIW             1.000000  \
# PF00001_PF00085          7       6H7O             0.857143
# PF00001_PF00087         44       6WJC             1.000000
# PF00001_PF00322         78       5GLH             1.000000
# PF00001_PF00339         38       6TKO             0.500000
# ...                    ...        ...                  ...
# PF18782_PF00559         23       6NIL             1.000000
# PF18784_PF00071         25       3NBZ             1.000000
# PF18801_PF00072         22       3Q15             1.000000
# PF18806_PF00071          7       2X19             1.000000
# PF18808_PF00071         11       3W3Z             1.000000
#
#                  Num_intrachain_structures
# DDI_type
# PF00001_PF00048                          0
# PF00001_PF00085                          1
# PF00001_PF00087                          0
# PF00001_PF00322                          0
# PF00001_PF00339                          3
# ...                                    ...
# PF18782_PF00559                          0
# PF18784_PF00071                          0
# PF18801_PF00072                          0
# PF18806_PF00071                          0
# PF18808_PF00071                          0
#
# [5724 rows x 12 columns]

# %%
# Filter df_joined for those clusters that include the max scoring structure in 3did
df_joined['PdbID'] = df_joined['PdbID'].str.split(',')

# %%
df_max_Score_joined = pd.merge(df_joined, df_inter_hetero.filter(['DDI_type', 'PDB_ID_max']), on= 'DDI_type')

# %%
df_max_Score_joined
# Out:
#                      DomainNames                               FileName
# 0                     Med21 Med4                (Med21)(Med4)_19935.txt  \
# 1                      PI3Ka SH2                 (PI3Ka)(SH2)_13501.txt
# 2       Pox_Rap94 RNA_pol_Rpb2_7  (Pox_Rap94)(RNA_pol_Rpb2_7)_35453.txt
# 3      Adeno_hexon_C Adeno_PVIII  (Adeno_hexon_C)(Adeno_PVIII)_1493.txt
# 4      Adeno_hexon_C Adeno_PVIII  (Adeno_hexon_C)(Adeno_PVIII)_1493.txt
# ...                          ...                                    ...
# 15273                   ig MHC_I                  (ig)(MHC_I)_18510.txt
# 15274                   ig MHC_I                  (ig)(MHC_I)_18510.txt
# 15275                   ig MHC_I                  (ig)(MHC_I)_18510.txt
# 15276                   ig MHC_I                  (ig)(MHC_I)_18510.txt
# 15277                   ig MHC_I                  (ig)(MHC_I)_18510.txt
#
#               DDI_type  ClusterID  SurfaceArea  MinSeqIdentity
# 0      PF11221_PF10018          1     481.3500            27.0  \
# 1      PF00613_PF00017          1     382.7833            97.0
# 2      PF03294_PF04560          1     480.2750            99.0
# 3      PF01310_PF03678          1     396.3250            33.0
# 4      PF01310_PF03678          2     298.4818            25.0
# ...                ...        ...          ...             ...
# 15273  PF00129_PF00047          4     190.0111            82.0
# 15274  PF00129_PF00047          5     170.8200            82.0
# 15275  PF00129_PF00047          6     228.2500            82.0
# 15276  PF00129_PF00047          7     184.0000            82.0
# 15277  PF00129_PF00047          8     118.1167            97.0
#
#        MediumSurfaceArea                                              PdbID
# 0                 506.75                                       [5oqm, 5n9j]  \
# 1                 347.40  [5swo, 5swp, 5itd, 5ul1, 5xgh, 4l1b, 3hiz, 5sw...
# 2                 527.35                                       [6rfl, 6ric]
# 3                 408.70         [6qi5, 6z7n, 5tx1, 6b1t, 3zif, 6cgv, 6yba]
# 4                 374.75               [6qi5, 6z7n, 5tx1, 6b1t, 6cgv, 6yba]
# ...                  ...                                                ...
# 15273             180.90         [3vh8, 7k81, 3wuw, 5t6z, 7k80, 5b39, 6v3j]
# 15274             164.70   [3vh8, 5t70, 7k81, 3wuw, 5t6z, 7k80, 5b39, 6v3j]
# 15275             260.05                     [3vh8, 7k81, 3wuw, 7k80, 6v3j]
# 15276             190.45                           [7k80, 3vh8, 7k81, 3wuw]
# 15277             120.40                                 [6ewa, 6ewc, 6ewo]
#
#                                                  UnpCode
# 0          MED21_SCHPO;MED4_SCHPO,MED21_YEAST;MED4_YEAST  \
# 1                                 PK3CA_HUMAN;P85A_HUMAN
# 2      Q1PIU7_9POXV;B9U1Q1_9POXV,B9U1I7_9POXV;B9U1Q1_...
# 3      CAPSH_ADE05;CAP8_ADE05,B2ZX09_ADE41;B5SNS9_ADE...
# 4      CAPSH_ADE05;CAP8_ADE05,B2ZX09_ADE41;B5SNS9_ADE...
# ...                                                  ...
# 15273  I3ZN84_HUMAN;KI3L1_HUMAN,A0A411J078_HUMAN;I6LE...
# 15274  KI3L1_HUMAN;HLAB_HUMAN,HLAB_HUMAN;KI3L1_HUMAN,...
# 15275  KI3L1_HUMAN;HLAB_HUMAN,HLAB_HUMAN;KI3L1_HUMAN,...
# 15276  A0A411J078_HUMAN;I6LEL9_HUMAN,A0A411J078_HUMAN...
# 15277                             HLAA_HUMAN;LIRB1_HUMAN
#
#                                                  Species
# 0      Saccharomyces cerevisiae (strain ATCC 204508 /...  \
# 1                              Homo sapiens;Homo sapiens
# 2        Vaccinia virus GLV-1h68;Vaccinia virus GLV-1h68
# 3      Lizard adenovirus 2;Lizard adenovirus 2,Human ...
# 4      Lizard adenovirus 2;Lizard adenovirus 2,Human ...
# ...                                                  ...
# 15273                          Homo sapiens;Homo sapiens
# 15274                          Homo sapiens;Homo sapiens
# 15275                          Homo sapiens;Homo sapiens
# 15276                          Homo sapiens;Homo sapiens
# 15277                          Homo sapiens;Homo sapiens
#
#                                   CFID PDB_ID_max
# 0                              2.0,6.0       5N9J
# 1                  3.0,2.0,4.0,1.0,6.0       5SWR
# 2                              2.0,1.0       6RFL
# 3          3.0,2.0,7.0,4.0,5.0,1.0,6.0       6CGV
# 4              3.0,2.0,4.0,5.0,1.0,6.0       6CGV
# ...                                ...        ...
# 15273  10.0,12.0,3.0,4.0,11.0,16.0,9.0       5T70
# 15274  10.0,12.0,3.0,4.0,11.0,16.0,9.0       5T70
# 15275            10.0,3.0,4.0,11.0,9.0       5T70
# 15276                 10.0,9.0,3.0,4.0       5T70
# 15277                             17.0       5T70
#
# [15278 rows x 12 columns]

# %%
data_test = {'Column1': [70, 65, 80, 95],
            'Column2': [['A', 'B', 'C'], ['B', 'C', 'D'], ['E', 'F', 'G'], ['X', 'Y', 'Z']],
            'Column3': ['PF1_PF2', 'PF1_PF2', 'PF3_PF4', 'PF3_PF4'],
            'Column4': ['B', 'B', 'E', 'E']}
df_test = pd.DataFrame(data_test)
#mask = (~df_test['Column4'].isin(df_test['Column2']))
mask= df_test.apply(lambda row: row['Column4'] in row['Column2'], axis=1)
df_test_filtered = df_test[mask]
df_test_filtered
# Out:
#    Column1    Column2  Column3 Column4
# 0       70  [A, B, C]  PF1_PF2       B
# 1       65  [B, C, D]  PF1_PF2       B
# 2       80  [E, F, G]  PF3_PF4       E

# %%
df_max_Score_joined['PDB_ID_max'] = df_max_Score_joined['PDB_ID_max'].astype(str)
df_max_Score_joined['PDB_ID_max'] = df_max_Score_joined['PDB_ID_max'].str.lower()

# Apply the ensure_list_of_strings function to the column to ensure that it holds lists of strings
df_max_Score_joined['PdbID'] = df_max_Score_joined['PdbID'].apply(ensure_list_of_strings)

# %%
df_max_Score_joined
# Out:
#                      DomainNames                               FileName
# 0                     Med21 Med4                (Med21)(Med4)_19935.txt  \
# 1                      PI3Ka SH2                 (PI3Ka)(SH2)_13501.txt
# 2       Pox_Rap94 RNA_pol_Rpb2_7  (Pox_Rap94)(RNA_pol_Rpb2_7)_35453.txt
# 3      Adeno_hexon_C Adeno_PVIII  (Adeno_hexon_C)(Adeno_PVIII)_1493.txt
# 4      Adeno_hexon_C Adeno_PVIII  (Adeno_hexon_C)(Adeno_PVIII)_1493.txt
# ...                          ...                                    ...
# 15273                   ig MHC_I                  (ig)(MHC_I)_18510.txt
# 15274                   ig MHC_I                  (ig)(MHC_I)_18510.txt
# 15275                   ig MHC_I                  (ig)(MHC_I)_18510.txt
# 15276                   ig MHC_I                  (ig)(MHC_I)_18510.txt
# 15277                   ig MHC_I                  (ig)(MHC_I)_18510.txt
#
#               DDI_type  ClusterID  SurfaceArea  MinSeqIdentity
# 0      PF11221_PF10018          1     481.3500            27.0  \
# 1      PF00613_PF00017          1     382.7833            97.0
# 2      PF03294_PF04560          1     480.2750            99.0
# 3      PF01310_PF03678          1     396.3250            33.0
# 4      PF01310_PF03678          2     298.4818            25.0
# ...                ...        ...          ...             ...
# 15273  PF00129_PF00047          4     190.0111            82.0
# 15274  PF00129_PF00047          5     170.8200            82.0
# 15275  PF00129_PF00047          6     228.2500            82.0
# 15276  PF00129_PF00047          7     184.0000            82.0
# 15277  PF00129_PF00047          8     118.1167            97.0
#
#        MediumSurfaceArea                                              PdbID
# 0                 506.75                                       [5oqm, 5n9j]  \
# 1                 347.40  [5swo, 5swp, 5itd, 5ul1, 5xgh, 4l1b, 3hiz, 5sw...
# 2                 527.35                                       [6rfl, 6ric]
# 3                 408.70         [6qi5, 6z7n, 5tx1, 6b1t, 3zif, 6cgv, 6yba]
# 4                 374.75               [6qi5, 6z7n, 5tx1, 6b1t, 6cgv, 6yba]
# ...                  ...                                                ...
# 15273             180.90         [3vh8, 7k81, 3wuw, 5t6z, 7k80, 5b39, 6v3j]
# 15274             164.70   [3vh8, 5t70, 7k81, 3wuw, 5t6z, 7k80, 5b39, 6v3j]
# 15275             260.05                     [3vh8, 7k81, 3wuw, 7k80, 6v3j]
# 15276             190.45                           [7k80, 3vh8, 7k81, 3wuw]
# 15277             120.40                                 [6ewa, 6ewc, 6ewo]
#
#                                                  UnpCode
# 0          MED21_SCHPO;MED4_SCHPO,MED21_YEAST;MED4_YEAST  \
# 1                                 PK3CA_HUMAN;P85A_HUMAN
# 2      Q1PIU7_9POXV;B9U1Q1_9POXV,B9U1I7_9POXV;B9U1Q1_...
# 3      CAPSH_ADE05;CAP8_ADE05,B2ZX09_ADE41;B5SNS9_ADE...
# 4      CAPSH_ADE05;CAP8_ADE05,B2ZX09_ADE41;B5SNS9_ADE...
# ...                                                  ...
# 15273  I3ZN84_HUMAN;KI3L1_HUMAN,A0A411J078_HUMAN;I6LE...
# 15274  KI3L1_HUMAN;HLAB_HUMAN,HLAB_HUMAN;KI3L1_HUMAN,...
# 15275  KI3L1_HUMAN;HLAB_HUMAN,HLAB_HUMAN;KI3L1_HUMAN,...
# 15276  A0A411J078_HUMAN;I6LEL9_HUMAN,A0A411J078_HUMAN...
# 15277                             HLAA_HUMAN;LIRB1_HUMAN
#
#                                                  Species
# 0      Saccharomyces cerevisiae (strain ATCC 204508 /...  \
# 1                              Homo sapiens;Homo sapiens
# 2        Vaccinia virus GLV-1h68;Vaccinia virus GLV-1h68
# 3      Lizard adenovirus 2;Lizard adenovirus 2,Human ...
# 4      Lizard adenovirus 2;Lizard adenovirus 2,Human ...
# ...                                                  ...
# 15273                          Homo sapiens;Homo sapiens
# 15274                          Homo sapiens;Homo sapiens
# 15275                          Homo sapiens;Homo sapiens
# 15276                          Homo sapiens;Homo sapiens
# 15277                          Homo sapiens;Homo sapiens
#
#                                   CFID PDB_ID_max
# 0                              2.0,6.0       5n9j
# 1                  3.0,2.0,4.0,1.0,6.0       5swr
# 2                              2.0,1.0       6rfl
# 3          3.0,2.0,7.0,4.0,5.0,1.0,6.0       6cgv
# 4              3.0,2.0,4.0,5.0,1.0,6.0       6cgv
# ...                                ...        ...
# 15273  10.0,12.0,3.0,4.0,11.0,16.0,9.0       5t70
# 15274  10.0,12.0,3.0,4.0,11.0,16.0,9.0       5t70
# 15275            10.0,3.0,4.0,11.0,9.0       5t70
# 15276                 10.0,9.0,3.0,4.0       5t70
# 15277                             17.0       5t70
#
# [15278 rows x 12 columns]

# %%
# Create a boolean mask based on the condition
mask = df_max_Score_joined.apply(lambda row: row['PDB_ID_max'] in row['PdbID'], axis=1)
# Use the boolean mask to filter and keep only the desired rows
df_max_Score_joined_filtered = df_max_Score_joined[mask]

# %%
df_max_Score_joined_filtered
# Out:
#                          DomainNames
# 0                         Med21 Med4  \
# 1                          PI3Ka SH2
# 2           Pox_Rap94 RNA_pol_Rpb2_7
# 3          Adeno_hexon_C Adeno_PVIII
# 4          Adeno_hexon_C Adeno_PVIII
# ...                              ...
# 15260         Fer4_7 NADH_Oxid_Nqo15
# 15269  Chordopox_RPO7 Pox_RNA_pol_35
# 15270                       ig MHC_I
# 15271                       ig MHC_I
# 15274                       ig MHC_I
#
#                                          FileName         DDI_type  ClusterID
# 0                         (Med21)(Med4)_19935.txt  PF11221_PF10018          1  \
# 1                          (PI3Ka)(SH2)_13501.txt  PF00613_PF00017          1
# 2           (Pox_Rap94)(RNA_pol_Rpb2_7)_35453.txt  PF03294_PF04560          1
# 3           (Adeno_hexon_C)(Adeno_PVIII)_1493.txt  PF01310_PF03678          1
# 4           (Adeno_hexon_C)(Adeno_PVIII)_1493.txt  PF01310_PF03678          2
# ...                                           ...              ...        ...
# 15260          (Fer4_7)(NADH_Oxid_Nqo15)_8080.txt  PF12838_PF11497          1
# 15269  (Chordopox_RPO7)(Pox_RNA_pol_35)_35486.txt  PF05864_PF03396          1
# 15270                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          1
# 15271                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          2
# 15274                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          5
#
#        SurfaceArea  MinSeqIdentity  MediumSurfaceArea
# 0         481.3500            27.0             506.75  \
# 1         382.7833            97.0             347.40
# 2         480.2750            99.0             527.35
# 3         396.3250            33.0             408.70
# 4         298.4818            25.0             374.75
# ...            ...             ...                ...
# 15260     323.8731            99.0             326.20
# 15269    1492.7250            98.0            1503.20
# 15270     311.3024            79.0             297.50
# 15271     243.0559            30.0             231.25
# 15274     170.8200            82.0             164.70
#
#                                                    PdbID
# 0                                           [5oqm, 5n9j]  \
# 1      [5swo, 5swp, 5itd, 5ul1, 5xgh, 4l1b, 3hiz, 5sw...
# 2                                           [6rfl, 6ric]
# 3             [6qi5, 6z7n, 5tx1, 6b1t, 3zif, 6cgv, 6yba]
# 4                   [6qi5, 6z7n, 5tx1, 6b1t, 6cgv, 6yba]
# ...                                                  ...
# 15260  [6i0d, 4hea, 6zjn, 6q8w, 3iam, 2ybb, 6ziy, 6zj...
# 15269                           [6rid, 6rfl, 6rie, 6ric]
# 15270  [6pa1, 1im9, 3vh8, 4n8v, 1efx, 5t70, 7k81, 3wu...
# 15271  [1im9, 3vh8, 4n8v, 5t70, 7k81, 3wuw, 5t6z, 7k8...
# 15274   [3vh8, 5t70, 7k81, 3wuw, 5t6z, 7k80, 5b39, 6v3j]
#
#                                                  UnpCode
# 0          MED21_SCHPO;MED4_SCHPO,MED21_YEAST;MED4_YEAST  \
# 1                                 PK3CA_HUMAN;P85A_HUMAN
# 2      Q1PIU7_9POXV;B9U1Q1_9POXV,B9U1I7_9POXV;B9U1Q1_...
# 3      CAPSH_ADE05;CAP8_ADE05,B2ZX09_ADE41;B5SNS9_ADE...
# 4      CAPSH_ADE05;CAP8_ADE05,B2ZX09_ADE41;B5SNS9_ADE...
# ...                                                  ...
# 15260                             NQO9_THET8;NQO15_THET8
# 15269    B9U1G3_9POXV;B9U1R2_9POXV,RP07_VACCA;RP35_VACCA
# 15270  KI2L2_HUMAN;HLAC_HUMAN,HLAB_HUMAN;KI3L1_HUMAN,...
# 15271  HLAB_HUMAN;KI3L1_HUMAN,KI2L1_HUMAN;HLAC_HUMAN,...
# 15274  KI3L1_HUMAN;HLAB_HUMAN,HLAB_HUMAN;KI3L1_HUMAN,...
#
#                                                  Species
# 0      Saccharomyces cerevisiae (strain ATCC 204508 /...  \
# 1                              Homo sapiens;Homo sapiens
# 2        Vaccinia virus GLV-1h68;Vaccinia virus GLV-1h68
# 3      Lizard adenovirus 2;Lizard adenovirus 2,Human ...
# 4      Lizard adenovirus 2;Lizard adenovirus 2,Human ...
# ...                                                  ...
# 15260  THERMUS THERMOPHILUS;THERMUS THERMOPHILUS,Ther...
# 15269  Vaccinia virus;Vaccinia virus,Vaccinia virus G...
# 15270                          Homo sapiens;Homo sapiens
# 15271                          Homo sapiens;Homo sapiens
# 15274                          Homo sapiens;Homo sapiens
#
#                                                     CFID PDB_ID_max
# 0                                                2.0,6.0       5n9j
# 1                                    3.0,2.0,4.0,1.0,6.0       5swr
# 2                                                2.0,1.0       6rfl
# 3                            3.0,2.0,7.0,4.0,5.0,1.0,6.0       6cgv
# 4                                3.0,2.0,4.0,5.0,1.0,6.0       6cgv
# ...                                                  ...        ...
# 15260                    3.0,2.0,8.0,9.0,4.0,5.0,1.0,6.0       4hea
# 15269                                    3.0,2.0,4.0,1.0       6rie
# 15270  10.0,12.0,14.0,3.0,8.0,4.0,11.0,5.0,16.0,1.0,9...       5t70
# 15271      10.0,12.0,14.0,3.0,4.0,11.0,5.0,16.0,9.0,15.0       5t70
# 15274                    10.0,12.0,3.0,4.0,11.0,16.0,9.0       5t70
#
# [4348 rows x 12 columns]

# %%
df_max_Score_joined_filtered = df_max_Score_joined_filtered.copy()
df_max_Score_joined_filtered['PdbID'] = df_max_Score_joined_filtered['PdbID'].str.join(',')

# %%
df_max_Score_joined_filtered
# Out:
#                          DomainNames
# 0                         Med21 Med4  \
# 1                          PI3Ka SH2
# 2           Pox_Rap94 RNA_pol_Rpb2_7
# 3          Adeno_hexon_C Adeno_PVIII
# 4          Adeno_hexon_C Adeno_PVIII
# ...                              ...
# 15260         Fer4_7 NADH_Oxid_Nqo15
# 15269  Chordopox_RPO7 Pox_RNA_pol_35
# 15270                       ig MHC_I
# 15271                       ig MHC_I
# 15274                       ig MHC_I
#
#                                          FileName         DDI_type  ClusterID
# 0                         (Med21)(Med4)_19935.txt  PF11221_PF10018          1  \
# 1                          (PI3Ka)(SH2)_13501.txt  PF00613_PF00017          1
# 2           (Pox_Rap94)(RNA_pol_Rpb2_7)_35453.txt  PF03294_PF04560          1
# 3           (Adeno_hexon_C)(Adeno_PVIII)_1493.txt  PF01310_PF03678          1
# 4           (Adeno_hexon_C)(Adeno_PVIII)_1493.txt  PF01310_PF03678          2
# ...                                           ...              ...        ...
# 15260          (Fer4_7)(NADH_Oxid_Nqo15)_8080.txt  PF12838_PF11497          1
# 15269  (Chordopox_RPO7)(Pox_RNA_pol_35)_35486.txt  PF05864_PF03396          1
# 15270                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          1
# 15271                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          2
# 15274                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          5
#
#        SurfaceArea  MinSeqIdentity  MediumSurfaceArea
# 0         481.3500            27.0             506.75  \
# 1         382.7833            97.0             347.40
# 2         480.2750            99.0             527.35
# 3         396.3250            33.0             408.70
# 4         298.4818            25.0             374.75
# ...            ...             ...                ...
# 15260     323.8731            99.0             326.20
# 15269    1492.7250            98.0            1503.20
# 15270     311.3024            79.0             297.50
# 15271     243.0559            30.0             231.25
# 15274     170.8200            82.0             164.70
#
#                                                    PdbID
# 0                                              5oqm,5n9j  \
# 1      5swo,5swp,5itd,5ul1,5xgh,4l1b,3hiz,5swr,4jps,4...
# 2                                              6rfl,6ric
# 3                     6qi5,6z7n,5tx1,6b1t,3zif,6cgv,6yba
# 4                          6qi5,6z7n,5tx1,6b1t,6cgv,6yba
# ...                                                  ...
# 15260  6i0d,4hea,6zjn,6q8w,3iam,2ybb,6ziy,6zjl,6q8x,3...
# 15269                                6rid,6rfl,6rie,6ric
# 15270  6pa1,1im9,3vh8,4n8v,1efx,5t70,7k81,3wuw,5t6z,7...
# 15271  1im9,3vh8,4n8v,5t70,7k81,3wuw,5t6z,7k80,5b39,6...
# 15274            3vh8,5t70,7k81,3wuw,5t6z,7k80,5b39,6v3j
#
#                                                  UnpCode
# 0          MED21_SCHPO;MED4_SCHPO,MED21_YEAST;MED4_YEAST  \
# 1                                 PK3CA_HUMAN;P85A_HUMAN
# 2      Q1PIU7_9POXV;B9U1Q1_9POXV,B9U1I7_9POXV;B9U1Q1_...
# 3      CAPSH_ADE05;CAP8_ADE05,B2ZX09_ADE41;B5SNS9_ADE...
# 4      CAPSH_ADE05;CAP8_ADE05,B2ZX09_ADE41;B5SNS9_ADE...
# ...                                                  ...
# 15260                             NQO9_THET8;NQO15_THET8
# 15269    B9U1G3_9POXV;B9U1R2_9POXV,RP07_VACCA;RP35_VACCA
# 15270  KI2L2_HUMAN;HLAC_HUMAN,HLAB_HUMAN;KI3L1_HUMAN,...
# 15271  HLAB_HUMAN;KI3L1_HUMAN,KI2L1_HUMAN;HLAC_HUMAN,...
# 15274  KI3L1_HUMAN;HLAB_HUMAN,HLAB_HUMAN;KI3L1_HUMAN,...
#
#                                                  Species
# 0      Saccharomyces cerevisiae (strain ATCC 204508 /...  \
# 1                              Homo sapiens;Homo sapiens
# 2        Vaccinia virus GLV-1h68;Vaccinia virus GLV-1h68
# 3      Lizard adenovirus 2;Lizard adenovirus 2,Human ...
# 4      Lizard adenovirus 2;Lizard adenovirus 2,Human ...
# ...                                                  ...
# 15260  THERMUS THERMOPHILUS;THERMUS THERMOPHILUS,Ther...
# 15269  Vaccinia virus;Vaccinia virus,Vaccinia virus G...
# 15270                          Homo sapiens;Homo sapiens
# 15271                          Homo sapiens;Homo sapiens
# 15274                          Homo sapiens;Homo sapiens
#
#                                                     CFID PDB_ID_max
# 0                                                2.0,6.0       5n9j
# 1                                    3.0,2.0,4.0,1.0,6.0       5swr
# 2                                                2.0,1.0       6rfl
# 3                            3.0,2.0,7.0,4.0,5.0,1.0,6.0       6cgv
# 4                                3.0,2.0,4.0,5.0,1.0,6.0       6cgv
# ...                                                  ...        ...
# 15260                    3.0,2.0,8.0,9.0,4.0,5.0,1.0,6.0       4hea
# 15269                                    3.0,2.0,4.0,1.0       6rie
# 15270  10.0,12.0,14.0,3.0,8.0,4.0,11.0,5.0,16.0,1.0,9...       5t70
# 15271      10.0,12.0,14.0,3.0,4.0,11.0,5.0,16.0,9.0,15.0       5t70
# 15274                    10.0,12.0,3.0,4.0,11.0,16.0,9.0       5t70
#
# [4348 rows x 12 columns]

# %%
df_max_Score_joined_filtered.to_csv('/Users/johgeist/Downloads/3did_project_dataframes_new/ProtCID_parsed_files/Master_df_ProtCID_20231017.csv', index=False)

# %%
# Create another datarame with the same columns but holding oonly the counts of the ProtCID features as values, as
# numeric features will be needed later
df_counts = df_max_Score_joined_filtered.drop(labels= ['UnpCode', 'CFID', 'PdbID', 'Species'], axis = 1)
df_counts['UnpCode'] = df_max_Score_joined_filtered['UnpCode'].str.count(",") + 1
df_counts['PdbID'] = df_max_Score_joined_filtered['PdbID'].str.count(",") + 1
df_counts['CFID'] = df_max_Score_joined_filtered['CFID'].str.count(",") + 1

df_counts
# Out:
#                          DomainNames
# 0                         Med21 Med4  \
# 1                          PI3Ka SH2
# 2           Pox_Rap94 RNA_pol_Rpb2_7
# 3          Adeno_hexon_C Adeno_PVIII
# 4          Adeno_hexon_C Adeno_PVIII
# ...                              ...
# 15260         Fer4_7 NADH_Oxid_Nqo15
# 15269  Chordopox_RPO7 Pox_RNA_pol_35
# 15270                       ig MHC_I
# 15271                       ig MHC_I
# 15274                       ig MHC_I
#
#                                          FileName         DDI_type  ClusterID
# 0                         (Med21)(Med4)_19935.txt  PF11221_PF10018          1  \
# 1                          (PI3Ka)(SH2)_13501.txt  PF00613_PF00017          1
# 2           (Pox_Rap94)(RNA_pol_Rpb2_7)_35453.txt  PF03294_PF04560          1
# 3           (Adeno_hexon_C)(Adeno_PVIII)_1493.txt  PF01310_PF03678          1
# 4           (Adeno_hexon_C)(Adeno_PVIII)_1493.txt  PF01310_PF03678          2
# ...                                           ...              ...        ...
# 15260          (Fer4_7)(NADH_Oxid_Nqo15)_8080.txt  PF12838_PF11497          1
# 15269  (Chordopox_RPO7)(Pox_RNA_pol_35)_35486.txt  PF05864_PF03396          1
# 15270                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          1
# 15271                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          2
# 15274                       (ig)(MHC_I)_18510.txt  PF00129_PF00047          5
#
#        SurfaceArea  MinSeqIdentity  MediumSurfaceArea PDB_ID_max  UnpCode
# 0         481.3500            27.0             506.75       5n9j        2  \
# 1         382.7833            97.0             347.40       5swr        1
# 2         480.2750            99.0             527.35       6rfl        2
# 3         396.3250            33.0             408.70       6cgv        6
# 4         298.4818            25.0             374.75       6cgv        5
# ...            ...             ...                ...        ...      ...
# 15260     323.8731            99.0             326.20       4hea        1
# 15269    1492.7250            98.0            1503.20       6rie        2
# 15270     311.3024            79.0             297.50       5t70        9
# 15271     243.0559            30.0             231.25       5t70        7
# 15274     170.8200            82.0             164.70       5t70        5
#
#        PdbID  CFID
# 0          2     2
# 1         30     5
# 2          2     2
# 3          7     7
# 4          6     6
# ...      ...   ...
# 15260     14     8
# 15269      4     4
# 15270     13    12
# 15271     11    10
# 15274      8     7
#
# [4348 rows x 11 columns]

# %%
df_counts.to_csv('/Users/johgeist/Downloads/3did_project_dataframes_new/ProtCID_parsed_files/Master_counts_df_ProtCID_20231017.csv', index= False)
